# %% [markdown]
# This notebook is the implementation of the <a href="https://github.com/manhlab/pratice-gan-2021-tutorial/tree/main/01-mnist-gan">first lab</a> of GAN course at ITMO university (Fall, 2021) by Arip Asadulaev.

# %% [markdown]
# ## GAN model

# %% [markdown]
# In 2014, Ian Goodfellow and his colleagues at the University of Montreal published a stunning paper introducing the world to GANs, or generative adversarial networks. The models play two distinct (literally, adversarial) roles. Given some real data set R, G is the generator, trying to create fake data that looks just like the genuine data, while D is the discriminator, getting data from either the real set or G and labeling the difference. Goodfellow’s metaphor (and a fine one it is) was that G was like a team of forgers trying to match real paintings with their output, while D was the team of detectives trying to tell the difference. (Except that in this case, the forgers G never get to see the original data — only the judgments of D. They’re like blind forgers.)
#
# Here's what we're going to do:
#
# - Define the parameters
# - Load the data (with transforms and normalization)
# - Denormalize for visual inspection of samples
# - Define the Discriminator network, the Generator network
# - Study the activation function: Leaky ReLU
# - Explain the output activation function: Tanh, Sigmoid
# - Look at some sample outputs
# - Define losses, optimizers and helper functions for training
#  - For discriminator
#  -  For generator
# - Train the model
# - Save intermediate generated images to file
# - Look at some outputs
# - Save the models
#
# ![MNIST](https://i.imgur.com/CAYnuo1.jpeg)

# %% [markdown]
# ### Load libraries

# %%
import torch 
import torch.nn as nn
import numpy as np
import cv2
import matplotlib.pyplot as plt
import torchvision
from torchvision.transforms import ToTensor, Normalize, Compose
from torchvision.datasets import MNIST
from IPython.display import Image
from torchvision.utils import save_image
from torch.utils.data import DataLoader

import os
# %matplotlib inline 
plt.style.use("ggplot")

# %% [markdown]
# ### Define parameters & Load Dataset

# %%
hidden_size = 256 
batch_size = 100 
LR = 0.0002
num_epochs = 300
sample_dir = "./images"
latent_size = 64 # input random input vector latent
image_size = 784 # 28*28 flatten
image_W = 28
image_H = 28
image_C = 1

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print("device used: ", device)
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)
## Define the dataset
mnist = MNIST(root='data', 
              train=True, 
              download=True,
              transform=Compose([ToTensor(), Normalize(mean=(0.5,), std=(0.5,))]))
# Out:
# device used:  cuda

# %%
# denormalization image from range (-1)-1 to range 0-1 to display it
def denorm(x):
    batch_size_ = x.size(0)
    x = x.view(batch_size_ , -1)
    x -= x.min(1, keepdim=True)[0]
    x /= x.max(1, keepdim=True)[0]
    x = x.view(batch_size_, image_C, image_H, image_W)
    return x

img, label = mnist[0]
img = denorm(img.unsqueeze(0)).squeeze(0) # The functions expects first dim to be batch_size
print("Min: ", img.min().item())
print("Max: ", img.max().item())
# Out:
# Min:  0.0
# Max:  1.0

# %%
# show image sample with matplotlib
def plot_torch_image(img, **kwargs):
    '''
    Input image is a torch tensor with the following dims (C,H,W)
    To plot it with matplotlib, we need to change it to (H,W,C) 
    kwargs varaible is used to pass other parameters to 'imshow' function.
    '''
    plt.imshow(img.permute(1, 2, 0) , **kwargs)
    
plot_torch_image(img,cmap='gray')

# %%
# define the dataloader
data_loader = DataLoader(mnist, batch_size=batch_size, shuffle=True)

# %% [markdown]
# GAN состоит из двух глубоких сетей, генератора и дискриминатора. генератор создает изображения, прежде чем научиться его обучать. Поскольку дискриминатор представляет собой модель бинарной классификации, мы можем использовать функцию потери бинарной кросс-энтропии для количественной оценки того, насколько хорошо он может различать реальные и сгенерированные изображения.
#
# The GAN consists of two deep networks, a generator and a discriminator. the generator creates images before learning how to train it. Since the discriminator is a binary classification model, we can use the binary cross-entropy loss function to quantify how well it can distinguish between real and generated images.
# ![](https://raw.githubusercontent.com/manhlab/practike-gan-2021/main/generator.png)
# ![](https://raw.githubusercontent.com/manhlab/practike-gan-2021/main/discriminator.png)

# %%
class Generator(nn.Module):
    def __init__(self, latent_size,image_size, hidden_size):
        super(Generator, self).__init__()
        ## set a linear layer with input size is latent_size and output size is hidden_size
        self.l1 = nn.Linear(latent_size, hidden_size)
        #set a linear layer with input size is hidden_size and output size is hidden_size
        self.l2 = nn.Linear(hidden_size, hidden_size)
        #set a linear layer with input size is hidden_size and output size is image_size
        self.l3 = nn.Linear(hidden_size, image_size)


    def forward(self, x):
        # forward x -> linear1 -> relu -> linear2 -> relu -> linear3 -> tanh
        x = self.l1(x)
        x = nn.ReLU()(x)
        x = self.l2(x)
        x = nn.ReLU()(x)
        x = self.l3(x)
        x = nn.Tanh()(x)        
        return x

class Discriminator(nn.Module):
    def __init__(self, image_size, hidden_size):
        super(Discriminator, self).__init__()
        ## set a linear layer with input size is image_size and output size is hidden_size
        self.l1 = nn.Linear(image_size, hidden_size)
        #set a linear layer with input size is hidden_size and output size is hidden_size
        self.l2 = nn.Linear(hidden_size, hidden_size)
        #set a linear layer with input size is hidden_size and output size is 1
        self.l3 = nn.Linear(hidden_size, 1)

        
    def forward(self, x):
        # forward x -> linear1 -> relu -> linear2 -> relu -> linear3 -> sigmoid
        x = self.l1(x)
        x = nn.ReLU()(x)
        x = self.l2(x)
        x = nn.ReLU()(x)
        x = self.l3(x)
        x = nn.Sigmoid()(x) 
        return x

# %% [markdown]
# ### Create the Generator and Discriminator

# %%
# create new Generator model
G = Generator(latent_size,image_size, hidden_size)
# create new Discriminator model
D = Discriminator(image_size, hidden_size)

# %%
# show an example of Generator output
y = G(torch.randn(2, latent_size))
for img in y:
    img= img.reshape(image_C,image_H,image_W)
    plt.figure()
    plot_torch_image(img.detach(),cmap='gray')

# %% [markdown]
# ### Define loss function and optimizers

# %%
# define the loss function to be used (Binary Cross Entropy)
loss_fn = nn.BCELoss()
## Define the optimizer for generator and discrimator
G_optim = torch.optim.Adam(G.parameters(), lr=LR)
D_optim = torch.optim.Adam(D.parameters(), lr=LR)

# %% [markdown]
# ### Discriminator Training

# %%
def reset_grad():
    ## reset gradient for optimizer of generator and discrimator
    G_optim.zero_grad()
    D_optim.zero_grad()
    

def train_discriminator(images):  
    # Create the labels which are later used as input for the BCE loss
    real_labels = torch.ones(batch_size, 1).to(device)
    fake_labels = torch.zeros(batch_size, 1).to(device)
        
    
    outputs = D(images)
    # Loss for real images
    loss_r = loss_fn(outputs, real_labels)
    real_score = outputs

    # Loss for fake images
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)
    outputs = D(fake_images)
    loss_f = loss_fn(outputs, fake_labels)
    fake_score = outputs

    # Sum losses
    d_loss = loss_r + loss_f
    # Adjust the parameters using backprop
    d_loss.backward()
    # Compute gradients
    D_optim.step()
    # Reset gradients
    reset_grad()

    return d_loss, real_score, fake_score

# %% [markdown]
# ### Generator Training

# %%
def train_generator():
    # Generate fake images and calculate loss
    # z = torch.randn(batch_size, latent_size).to(device)
    z = torch.Tensor(np.random.normal(0, 1, (batch_size, latent_size))).to(device)
    fake_images = G(z)
    labels = torch.ones(batch_size, 1).to(device)
    # calculate the generator loss
    outputs = D(fake_images)
    g_loss = loss_fn(outputs, labels)
    # Backprop and optimize
    g_loss.backward()
    G_optim.step()
    # Reset gradients
    reset_grad()
    return g_loss, fake_images

# %% [markdown]
# ### Function to save the sample output of generator

# %%
def save_fake_images(index):
    # sample_vectors = torch.randn(batch_size, latent_size).to(device)
    sample_vectors = torch.Tensor(np.random.normal(0, 1, (batch_size, latent_size))).to(device)
    fake_images = G(sample_vectors)
    fake_images = fake_images.reshape(fake_images.size(0), 1, 28, 28)
    fake_fname = 'fake_images-{0:0=4d}.png'.format(index)
    print('Saving', fake_fname)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=10)

# %% [markdown]
# ## Start the training proccess

# %%
# %%time
total_step = len(data_loader)
d_losses, g_losses, real_scores, fake_scores = [], [], [], []
G.to(device)
D.to(device)
for epoch in range(num_epochs):
    for i, (images, _) in enumerate(data_loader):
        # Load a batch & transform to vectors
        images = images.reshape(batch_size, -1).to(device)
        
        # Train the discriminator  
        d_loss, real_score, fake_score = train_discriminator(images)
        # Train the generator
        g_loss, fake_images = train_generator()
        # Inspect the losses
        if (i+1) % 200 == 0:
            d_losses.append(d_loss.item())
            g_losses.append(g_loss.item())
            real_scores.append(real_score.mean().item())
            fake_scores.append(fake_score.mean().item())
            print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}' 
                  .format(epoch, num_epochs, i+1, total_step, d_loss.item(), g_loss.item(), 
                          real_score.mean().item(), fake_score.mean().item()))
    # Sample and save images
    save_fake_images(epoch+1)
# Out:
# Epoch [0/300], Step [200/600], d_loss: 0.3146, g_loss: 1.9765, D(x): 0.93, D(G(z)): 0.21
# Epoch [0/300], Step [400/600], d_loss: 0.3021, g_loss: 3.5178, D(x): 0.88, D(G(z)): 0.12
# Epoch [0/300], Step [600/600], d_loss: 0.2589, g_loss: 3.9085, D(x): 0.90, D(G(z)): 0.11
# Saving fake_images-0001.png
# Epoch [1/300], Step [200/600], d_loss: 0.1563, g_loss: 4.1865, D(x): 0.92, D(G(z)): 0.05
# Epoch [1/300], Step [400/600], d_loss: 0.1363, g_loss: 4.1012, D(x): 0.99, D(G(z)): 0.12
# Epoch [1/300], Step [600/600], d_loss: 0.2715, g_loss: 4.1692, D(x): 0.91, D(G(z)): 0.09
# Saving fake_images-0002.png
# Epoch [2/300], Step [200/600], d_loss: 0.6028, g_loss: 2.3040, D(x): 0.78, D(G(z)): 0.12
# Epoch [2/300], Step [400/600], d_loss: 0.2710, g_loss: 3.4094, D(x): 0.87, D(G(z)): 0.06
# Epoch [2/300], Step [600/600], d_loss: 0.3178, g_loss: 2.8027, D(x): 0.89, D(G(z)): 0.10
# Saving fake_images-0003.png
# Epoch [3/300], Step [200/600], d_loss: 1.4944, g_loss: 2.0285, D(x): 0.70, D(G(z)): 0.46
# Epoch [3/300], Step [400/600], d_loss: 0.5190, g_loss: 3.5289, D(x): 0.87, D(G(z)): 0.18
# Epoch [3/300], Step [600/600], d_loss: 0.1532, g_loss: 4.0026, D(x): 0.93, D(G(z)): 0.04
# Saving fake_images-0004.png
# Epoch [4/300], Step [200/600], d_loss: 0.1563, g_loss: 3.8379, D(x): 0.95, D(G(z)): 0.08
# Epoch [4/300], Step [400/600], d_loss: 0.4695, g_loss: 3.0506, D(x): 0.89, D(G(z)): 0.22
# Epoch [4/300], Step [600/600], d_loss: 0.1932, g_loss: 5.3932, D(x): 0.93, D(G(z)): 0.01
# Saving fake_images-0005.png
# Epoch [5/300], Step [200/600], d_loss: 0.4901, g_loss: 3.1794, D(x): 0.84, D(G(z)): 0.08
# Epoch [5/300], Step [400/600], d_loss: 0.2379, g_loss: 3.6679, D(x): 0.92, D(G(z)): 0.10
# Epoch [5/300], Step [600/600], d_loss: 0.7765, g_loss: 1.9083, D(x): 0.80, D(G(z)): 0.28
# Saving fake_images-0006.png
# Epoch [6/300], Step [200/600], d_loss: 0.3850, g_loss: 2.9453, D(x): 0.86, D(G(z)): 0.12
# Epoch [6/300], Step [400/600], d_loss: 0.7551, g_loss: 2.9240, D(x): 0.79, D(G(z)): 0.22
# Epoch [6/300], Step [600/600], d_loss: 0.9667, g_loss: 0.9224, D(x): 0.72, D(G(z)): 0.31
# Saving fake_images-0007.png
# Epoch [7/300], Step [200/600], d_loss: 0.7977, g_loss: 2.1957, D(x): 0.78, D(G(z)): 0.30
# Epoch [7/300], Step [400/600], d_loss: 0.5898, g_loss: 2.4622, D(x): 0.81, D(G(z)): 0.14
# Epoch [7/300], Step [600/600], d_loss: 0.7957, g_loss: 1.5837, D(x): 0.76, D(G(z)): 0.21
# Saving fake_images-0008.png
# Epoch [8/300], Step [200/600], d_loss: 0.5520, g_loss: 2.3545, D(x): 0.86, D(G(z)): 0.25
# Epoch [8/300], Step [400/600], d_loss: 0.5983, g_loss: 3.4105, D(x): 0.82, D(G(z)): 0.10
# Epoch [8/300], Step [600/600], d_loss: 0.1742, g_loss: 3.0301, D(x): 0.94, D(G(z)): 0.10
# Saving fake_images-0009.png
# Epoch [9/300], Step [200/600], d_loss: 0.4415, g_loss: 3.0376, D(x): 0.90, D(G(z)): 0.17
# Epoch [9/300], Step [400/600], d_loss: 0.3091, g_loss: 2.9128, D(x): 0.89, D(G(z)): 0.09
# Epoch [9/300], Step [600/600], d_loss: 0.0759, g_loss: 4.2155, D(x): 0.99, D(G(z)): 0.06
# Saving fake_images-0010.png
# Epoch [10/300], Step [200/600], d_loss: 0.4703, g_loss: 3.4149, D(x): 0.88, D(G(z)): 0.09
# Epoch [10/300], Step [400/600], d_loss: 0.2399, g_loss: 6.2205, D(x): 0.90, D(G(z)): 0.03
# Epoch [10/300], Step [600/600], d_loss: 0.7897, g_loss: 3.3978, D(x): 0.79, D(G(z)): 0.15
# Saving fake_images-0011.png
# Epoch [11/300], Step [200/600], d_loss: 0.6956, g_loss: 2.3666, D(x): 0.82, D(G(z)): 0.15
# Epoch [11/300], Step [400/600], d_loss: 0.5900, g_loss: 2.6923, D(x): 0.85, D(G(z)): 0.17
# Epoch [11/300], Step [600/600], d_loss: 0.3470, g_loss: 3.5904, D(x): 0.93, D(G(z)): 0.19
# Saving fake_images-0012.png
# Epoch [12/300], Step [200/600], d_loss: 0.7247, g_loss: 3.0295, D(x): 0.83, D(G(z)): 0.27
# Epoch [12/300], Step [400/600], d_loss: 0.3019, g_loss: 3.8607, D(x): 0.89, D(G(z)): 0.09
# Epoch [12/300], Step [600/600], d_loss: 0.6330, g_loss: 2.7622, D(x): 0.88, D(G(z)): 0.29
# Saving fake_images-0013.png
# Epoch [13/300], Step [200/600], d_loss: 0.4906, g_loss: 2.8574, D(x): 0.86, D(G(z)): 0.19
# Epoch [13/300], Step [400/600], d_loss: 0.3500, g_loss: 3.1321, D(x): 0.86, D(G(z)): 0.11
# Epoch [13/300], Step [600/600], d_loss: 0.4102, g_loss: 2.6428, D(x): 0.86, D(G(z)): 0.10
# Saving fake_images-0014.png
# Epoch [14/300], Step [200/600], d_loss: 0.3001, g_loss: 2.6401, D(x): 0.92, D(G(z)): 0.12
# Epoch [14/300], Step [400/600], d_loss: 0.2954, g_loss: 3.4116, D(x): 0.90, D(G(z)): 0.11
# Epoch [14/300], Step [600/600], d_loss: 0.3475, g_loss: 2.9731, D(x): 0.91, D(G(z)): 0.17
# Saving fake_images-0015.png
# Epoch [15/300], Step [200/600], d_loss: 0.2832, g_loss: 3.5285, D(x): 0.92, D(G(z)): 0.11
# Epoch [15/300], Step [400/600], d_loss: 0.4270, g_loss: 3.4027, D(x): 0.83, D(G(z)): 0.10
# Epoch [15/300], Step [600/600], d_loss: 0.2986, g_loss: 2.8270, D(x): 0.90, D(G(z)): 0.09
# Saving fake_images-0016.png
# Epoch [16/300], Step [200/600], d_loss: 0.5153, g_loss: 3.7758, D(x): 0.88, D(G(z)): 0.18
# Epoch [16/300], Step [400/600], d_loss: 0.4224, g_loss: 3.7851, D(x): 0.92, D(G(z)): 0.21
# Epoch [16/300], Step [600/600], d_loss: 0.4541, g_loss: 3.0668, D(x): 0.87, D(G(z)): 0.11
# Saving fake_images-0017.png
# Epoch [17/300], Step [200/600], d_loss: 0.2885, g_loss: 3.5405, D(x): 0.96, D(G(z)): 0.16
# Epoch [17/300], Step [400/600], d_loss: 0.1578, g_loss: 3.8636, D(x): 0.94, D(G(z)): 0.06
# Epoch [17/300], Step [600/600], d_loss: 0.7563, g_loss: 2.7664, D(x): 0.84, D(G(z)): 0.25
# Saving fake_images-0018.png
# Epoch [18/300], Step [200/600], d_loss: 0.2748, g_loss: 3.7290, D(x): 0.91, D(G(z)): 0.10
# Epoch [18/300], Step [400/600], d_loss: 0.2794, g_loss: 4.1579, D(x): 0.91, D(G(z)): 0.11
# Epoch [18/300], Step [600/600], d_loss: 0.8777, g_loss: 2.1013, D(x): 0.78, D(G(z)): 0.21
# Saving fake_images-0019.png
# Epoch [19/300], Step [200/600], d_loss: 0.6222, g_loss: 2.5576, D(x): 0.91, D(G(z)): 0.30
# Epoch [19/300], Step [400/600], d_loss: 0.2950, g_loss: 4.0013, D(x): 0.88, D(G(z)): 0.08
# Epoch [19/300], Step [600/600], d_loss: 0.4811, g_loss: 2.6870, D(x): 0.89, D(G(z)): 0.21
# Saving fake_images-0020.png
# Epoch [20/300], Step [200/600], d_loss: 0.5462, g_loss: 3.3568, D(x): 0.80, D(G(z)): 0.10
# Epoch [20/300], Step [400/600], d_loss: 0.6793, g_loss: 2.6695, D(x): 0.84, D(G(z)): 0.21
# Epoch [20/300], Step [600/600], d_loss: 0.7876, g_loss: 3.2023, D(x): 0.77, D(G(z)): 0.12
# Saving fake_images-0021.png
# Epoch [21/300], Step [200/600], d_loss: 0.6751, g_loss: 1.9764, D(x): 0.83, D(G(z)): 0.24
# Epoch [21/300], Step [400/600], d_loss: 0.3321, g_loss: 2.5217, D(x): 0.91, D(G(z)): 0.14
# Epoch [21/300], Step [600/600], d_loss: 0.5389, g_loss: 2.5804, D(x): 0.77, D(G(z)): 0.10
# Saving fake_images-0022.png
# Epoch [22/300], Step [200/600], d_loss: 0.7792, g_loss: 2.3295, D(x): 0.88, D(G(z)): 0.30
# Epoch [22/300], Step [400/600], d_loss: 0.3133, g_loss: 3.9697, D(x): 0.88, D(G(z)): 0.09
# Epoch [22/300], Step [600/600], d_loss: 0.6604, g_loss: 2.9780, D(x): 0.84, D(G(z)): 0.22
# Saving fake_images-0023.png
# Epoch [23/300], Step [200/600], d_loss: 0.4311, g_loss: 4.9189, D(x): 0.82, D(G(z)): 0.05
# Epoch [23/300], Step [400/600], d_loss: 0.2738, g_loss: 3.7159, D(x): 0.90, D(G(z)): 0.10
# Epoch [23/300], Step [600/600], d_loss: 0.4351, g_loss: 3.4125, D(x): 0.86, D(G(z)): 0.10
# Saving fake_images-0024.png
# Epoch [24/300], Step [200/600], d_loss: 0.3458, g_loss: 3.5034, D(x): 0.89, D(G(z)): 0.14
# Epoch [24/300], Step [400/600], d_loss: 0.6832, g_loss: 1.7953, D(x): 0.87, D(G(z)): 0.28
# Epoch [24/300], Step [600/600], d_loss: 0.2400, g_loss: 5.0502, D(x): 0.87, D(G(z)): 0.04
# Saving fake_images-0025.png
# Epoch [25/300], Step [200/600], d_loss: 0.4744, g_loss: 3.0343, D(x): 0.91, D(G(z)): 0.21
# Epoch [25/300], Step [400/600], d_loss: 0.3133, g_loss: 3.6505, D(x): 0.86, D(G(z)): 0.06
# Epoch [25/300], Step [600/600], d_loss: 0.3847, g_loss: 4.2634, D(x): 0.89, D(G(z)): 0.12
# Saving fake_images-0026.png
# Epoch [26/300], Step [200/600], d_loss: 0.3003, g_loss: 4.7764, D(x): 0.90, D(G(z)): 0.09
# Epoch [26/300], Step [400/600], d_loss: 0.4300, g_loss: 3.3318, D(x): 0.86, D(G(z)): 0.07
# Epoch [26/300], Step [600/600], d_loss: 0.3554, g_loss: 4.2627, D(x): 0.88, D(G(z)): 0.12
# Saving fake_images-0027.png
# Epoch [27/300], Step [200/600], d_loss: 0.4781, g_loss: 3.4586, D(x): 0.81, D(G(z)): 0.08
# Epoch [27/300], Step [400/600], d_loss: 0.5580, g_loss: 2.8742, D(x): 0.82, D(G(z)): 0.12
# Epoch [27/300], Step [600/600], d_loss: 0.3377, g_loss: 3.8557, D(x): 0.84, D(G(z)): 0.06
# Saving fake_images-0028.png
# Epoch [28/300], Step [200/600], d_loss: 0.4815, g_loss: 3.1183, D(x): 0.85, D(G(z)): 0.13
# Epoch [28/300], Step [400/600], d_loss: 0.4702, g_loss: 3.2736, D(x): 0.88, D(G(z)): 0.22
# Epoch [28/300], Step [600/600], d_loss: 0.4579, g_loss: 2.4768, D(x): 0.89, D(G(z)): 0.18
# Saving fake_images-0029.png
# Epoch [29/300], Step [200/600], d_loss: 0.3932, g_loss: 3.2264, D(x): 0.85, D(G(z)): 0.08
# Epoch [29/300], Step [400/600], d_loss: 0.5601, g_loss: 2.6204, D(x): 0.93, D(G(z)): 0.29
# Epoch [29/300], Step [600/600], d_loss: 0.5492, g_loss: 3.6144, D(x): 0.83, D(G(z)): 0.14
# Saving fake_images-0030.png
# Epoch [30/300], Step [200/600], d_loss: 0.4922, g_loss: 2.1958, D(x): 0.82, D(G(z)): 0.13
# Epoch [30/300], Step [400/600], d_loss: 0.4339, g_loss: 3.0021, D(x): 0.90, D(G(z)): 0.19
# Epoch [30/300], Step [600/600], d_loss: 0.5978, g_loss: 2.8147, D(x): 0.77, D(G(z)): 0.08
# Saving fake_images-0031.png
# Epoch [31/300], Step [200/600], d_loss: 0.4890, g_loss: 2.9356, D(x): 0.83, D(G(z)): 0.12
# Epoch [31/300], Step [400/600], d_loss: 0.6532, g_loss: 2.8351, D(x): 0.88, D(G(z)): 0.26
# Epoch [31/300], Step [600/600], d_loss: 0.5509, g_loss: 2.7565, D(x): 0.89, D(G(z)): 0.25
# Saving fake_images-0032.png
# Epoch [32/300], Step [200/600], d_loss: 0.3205, g_loss: 3.4107, D(x): 0.89, D(G(z)): 0.12
# Epoch [32/300], Step [400/600], d_loss: 0.5951, g_loss: 2.2776, D(x): 0.81, D(G(z)): 0.19
# Epoch [32/300], Step [600/600], d_loss: 0.3825, g_loss: 2.4237, D(x): 0.92, D(G(z)): 0.20
# Saving fake_images-0033.png
# Epoch [33/300], Step [200/600], d_loss: 0.6236, g_loss: 1.9636, D(x): 0.88, D(G(z)): 0.27
# Epoch [33/300], Step [400/600], d_loss: 0.7931, g_loss: 2.3224, D(x): 0.77, D(G(z)): 0.20
# Epoch [33/300], Step [600/600], d_loss: 0.6115, g_loss: 2.4801, D(x): 0.80, D(G(z)): 0.18
# Saving fake_images-0034.png
# Epoch [34/300], Step [200/600], d_loss: 0.4952, g_loss: 2.6623, D(x): 0.85, D(G(z)): 0.18
# Epoch [34/300], Step [400/600], d_loss: 0.4457, g_loss: 2.6028, D(x): 0.84, D(G(z)): 0.15
# Epoch [34/300], Step [600/600], d_loss: 0.6923, g_loss: 2.2864, D(x): 0.80, D(G(z)): 0.20
# Saving fake_images-0035.png
# Epoch [35/300], Step [200/600], d_loss: 0.4042, g_loss: 2.9426, D(x): 0.90, D(G(z)): 0.19
# Epoch [35/300], Step [400/600], d_loss: 0.4816, g_loss: 2.9186, D(x): 0.87, D(G(z)): 0.16
# Epoch [35/300], Step [600/600], d_loss: 0.5512, g_loss: 1.9388, D(x): 0.89, D(G(z)): 0.24
# Saving fake_images-0036.png
# Epoch [36/300], Step [200/600], d_loss: 0.3266, g_loss: 2.5979, D(x): 0.91, D(G(z)): 0.14
# Epoch [36/300], Step [400/600], d_loss: 0.7136, g_loss: 2.7100, D(x): 0.87, D(G(z)): 0.29
# Epoch [36/300], Step [600/600], d_loss: 0.3356, g_loss: 3.2924, D(x): 0.89, D(G(z)): 0.12
# Saving fake_images-0037.png
# Epoch [37/300], Step [200/600], d_loss: 0.5228, g_loss: 2.8699, D(x): 0.93, D(G(z)): 0.26
# Epoch [37/300], Step [400/600], d_loss: 0.5325, g_loss: 3.1127, D(x): 0.80, D(G(z)): 0.09
# Epoch [37/300], Step [600/600], d_loss: 0.3261, g_loss: 3.0021, D(x): 0.89, D(G(z)): 0.12
# Saving fake_images-0038.png
# Epoch [38/300], Step [200/600], d_loss: 0.5298, g_loss: 2.2955, D(x): 0.89, D(G(z)): 0.24
# Epoch [38/300], Step [400/600], d_loss: 0.8170, g_loss: 2.0534, D(x): 0.74, D(G(z)): 0.17
# Epoch [38/300], Step [600/600], d_loss: 0.4188, g_loss: 3.2841, D(x): 0.87, D(G(z)): 0.15
# Saving fake_images-0039.png
# Epoch [39/300], Step [200/600], d_loss: 0.7320, g_loss: 2.4195, D(x): 0.73, D(G(z)): 0.16
# Epoch [39/300], Step [400/600], d_loss: 0.5174, g_loss: 2.1838, D(x): 0.82, D(G(z)): 0.17
# Epoch [39/300], Step [600/600], d_loss: 0.7346, g_loss: 2.1044, D(x): 0.73, D(G(z)): 0.17
# Saving fake_images-0040.png
# Epoch [40/300], Step [200/600], d_loss: 0.4993, g_loss: 3.6454, D(x): 0.76, D(G(z)): 0.09
# Epoch [40/300], Step [400/600], d_loss: 0.8686, g_loss: 2.4011, D(x): 0.78, D(G(z)): 0.26
# Epoch [40/300], Step [600/600], d_loss: 0.6321, g_loss: 2.1741, D(x): 0.77, D(G(z)): 0.18
# Saving fake_images-0041.png
# Epoch [41/300], Step [200/600], d_loss: 0.7064, g_loss: 2.1171, D(x): 0.81, D(G(z)): 0.25
# Epoch [41/300], Step [400/600], d_loss: 0.5963, g_loss: 2.6371, D(x): 0.77, D(G(z)): 0.16
# Epoch [41/300], Step [600/600], d_loss: 0.5862, g_loss: 1.8468, D(x): 0.85, D(G(z)): 0.23
# Saving fake_images-0042.png
# Epoch [42/300], Step [200/600], d_loss: 0.7799, g_loss: 2.1774, D(x): 0.78, D(G(z)): 0.28
# Epoch [42/300], Step [400/600], d_loss: 0.6114, g_loss: 2.3295, D(x): 0.85, D(G(z)): 0.24
# Epoch [42/300], Step [600/600], d_loss: 0.5193, g_loss: 2.4127, D(x): 0.84, D(G(z)): 0.21
# Saving fake_images-0043.png
# Epoch [43/300], Step [200/600], d_loss: 0.6334, g_loss: 2.7686, D(x): 0.75, D(G(z)): 0.12
# Epoch [43/300], Step [400/600], d_loss: 0.5045, g_loss: 2.7045, D(x): 0.82, D(G(z)): 0.14
# Epoch [43/300], Step [600/600], d_loss: 0.4846, g_loss: 1.9714, D(x): 0.91, D(G(z)): 0.24
# Saving fake_images-0044.png
# Epoch [44/300], Step [200/600], d_loss: 0.7438, g_loss: 2.3940, D(x): 0.77, D(G(z)): 0.21
# Epoch [44/300], Step [400/600], d_loss: 0.8189, g_loss: 2.0979, D(x): 0.71, D(G(z)): 0.21
# Epoch [44/300], Step [600/600], d_loss: 0.7832, g_loss: 2.6749, D(x): 0.74, D(G(z)): 0.20
# Saving fake_images-0045.png
# Epoch [45/300], Step [200/600], d_loss: 0.8290, g_loss: 1.8012, D(x): 0.73, D(G(z)): 0.23
# Epoch [45/300], Step [400/600], d_loss: 0.6718, g_loss: 2.4678, D(x): 0.73, D(G(z)): 0.16
# Epoch [45/300], Step [600/600], d_loss: 0.6192, g_loss: 2.6951, D(x): 0.78, D(G(z)): 0.17
# Saving fake_images-0046.png
# Epoch [46/300], Step [200/600], d_loss: 0.7424, g_loss: 1.7201, D(x): 0.79, D(G(z)): 0.26
# Epoch [46/300], Step [400/600], d_loss: 0.7816, g_loss: 2.6129, D(x): 0.74, D(G(z)): 0.18
# Epoch [46/300], Step [600/600], d_loss: 0.5360, g_loss: 2.6643, D(x): 0.81, D(G(z)): 0.15
# Saving fake_images-0047.png
# Epoch [47/300], Step [200/600], d_loss: 0.6658, g_loss: 2.0864, D(x): 0.77, D(G(z)): 0.20
# Epoch [47/300], Step [400/600], d_loss: 0.5889, g_loss: 2.3194, D(x): 0.82, D(G(z)): 0.20
# Epoch [47/300], Step [600/600], d_loss: 0.4933, g_loss: 2.4441, D(x): 0.85, D(G(z)): 0.17
# Saving fake_images-0048.png
# Epoch [48/300], Step [200/600], d_loss: 0.6277, g_loss: 2.4300, D(x): 0.79, D(G(z)): 0.18
# Epoch [48/300], Step [400/600], d_loss: 0.6704, g_loss: 2.0091, D(x): 0.78, D(G(z)): 0.22
# Epoch [48/300], Step [600/600], d_loss: 0.7777, g_loss: 1.7975, D(x): 0.76, D(G(z)): 0.21
# Saving fake_images-0049.png
# Epoch [49/300], Step [200/600], d_loss: 0.5561, g_loss: 1.8964, D(x): 0.81, D(G(z)): 0.20
# Epoch [49/300], Step [400/600], d_loss: 0.7821, g_loss: 2.0097, D(x): 0.74, D(G(z)): 0.23
# Epoch [49/300], Step [600/600], d_loss: 0.6366, g_loss: 2.4495, D(x): 0.82, D(G(z)): 0.24
# Saving fake_images-0050.png
# Epoch [50/300], Step [200/600], d_loss: 0.7198, g_loss: 2.5563, D(x): 0.77, D(G(z)): 0.18
# Epoch [50/300], Step [400/600], d_loss: 0.6657, g_loss: 2.2664, D(x): 0.80, D(G(z)): 0.21
# Epoch [50/300], Step [600/600], d_loss: 0.6789, g_loss: 1.4975, D(x): 0.82, D(G(z)): 0.28
# Saving fake_images-0051.png
# Epoch [51/300], Step [200/600], d_loss: 0.7879, g_loss: 2.0344, D(x): 0.79, D(G(z)): 0.25
# Epoch [51/300], Step [400/600], d_loss: 0.6353, g_loss: 2.0541, D(x): 0.80, D(G(z)): 0.21
# Epoch [51/300], Step [600/600], d_loss: 0.5246, g_loss: 2.4764, D(x): 0.81, D(G(z)): 0.16
# Saving fake_images-0052.png
# Epoch [52/300], Step [200/600], d_loss: 0.6934, g_loss: 2.3394, D(x): 0.80, D(G(z)): 0.24
# Epoch [52/300], Step [400/600], d_loss: 0.9031, g_loss: 1.7190, D(x): 0.82, D(G(z)): 0.37
# Epoch [52/300], Step [600/600], d_loss: 0.6112, g_loss: 1.8615, D(x): 0.79, D(G(z)): 0.20
# Saving fake_images-0053.png
# Epoch [53/300], Step [200/600], d_loss: 0.5179, g_loss: 2.2795, D(x): 0.83, D(G(z)): 0.17
# Epoch [53/300], Step [400/600], d_loss: 0.6368, g_loss: 1.9146, D(x): 0.85, D(G(z)): 0.29
# Epoch [53/300], Step [600/600], d_loss: 0.5684, g_loss: 2.2650, D(x): 0.79, D(G(z)): 0.19
# Saving fake_images-0054.png
# Epoch [54/300], Step [200/600], d_loss: 0.7900, g_loss: 2.1286, D(x): 0.74, D(G(z)): 0.20
# Epoch [54/300], Step [400/600], d_loss: 0.5274, g_loss: 2.2407, D(x): 0.84, D(G(z)): 0.17
# Epoch [54/300], Step [600/600], d_loss: 0.8677, g_loss: 1.6604, D(x): 0.73, D(G(z)): 0.26
# Saving fake_images-0055.png
# Epoch [55/300], Step [200/600], d_loss: 0.8582, g_loss: 1.9814, D(x): 0.75, D(G(z)): 0.27
# Epoch [55/300], Step [400/600], d_loss: 0.7477, g_loss: 2.0966, D(x): 0.81, D(G(z)): 0.29
# Epoch [55/300], Step [600/600], d_loss: 0.7768, g_loss: 2.2485, D(x): 0.82, D(G(z)): 0.27
# Saving fake_images-0056.png
# Epoch [56/300], Step [200/600], d_loss: 0.6562, g_loss: 1.4512, D(x): 0.84, D(G(z)): 0.30
# Epoch [56/300], Step [400/600], d_loss: 0.6774, g_loss: 2.1060, D(x): 0.83, D(G(z)): 0.27
# Epoch [56/300], Step [600/600], d_loss: 0.6815, g_loss: 2.3926, D(x): 0.75, D(G(z)): 0.17
# Saving fake_images-0057.png
# Epoch [57/300], Step [200/600], d_loss: 0.7823, g_loss: 2.3843, D(x): 0.80, D(G(z)): 0.27
# Epoch [57/300], Step [400/600], d_loss: 0.8823, g_loss: 1.8747, D(x): 0.73, D(G(z)): 0.28
# Epoch [57/300], Step [600/600], d_loss: 0.8307, g_loss: 2.0477, D(x): 0.74, D(G(z)): 0.27
# Saving fake_images-0058.png
# Epoch [58/300], Step [200/600], d_loss: 0.7827, g_loss: 1.7757, D(x): 0.79, D(G(z)): 0.29
# Epoch [58/300], Step [400/600], d_loss: 0.5154, g_loss: 2.3142, D(x): 0.83, D(G(z)): 0.18
# Epoch [58/300], Step [600/600], d_loss: 0.8865, g_loss: 2.0639, D(x): 0.77, D(G(z)): 0.27
# Saving fake_images-0059.png
# Epoch [59/300], Step [200/600], d_loss: 1.1711, g_loss: 1.3725, D(x): 0.72, D(G(z)): 0.40
# Epoch [59/300], Step [400/600], d_loss: 0.9153, g_loss: 1.8313, D(x): 0.74, D(G(z)): 0.32
# Epoch [59/300], Step [600/600], d_loss: 0.7886, g_loss: 1.4611, D(x): 0.75, D(G(z)): 0.26
# Saving fake_images-0060.png
# Epoch [60/300], Step [200/600], d_loss: 0.9425, g_loss: 1.9215, D(x): 0.68, D(G(z)): 0.23
# Epoch [60/300], Step [400/600], d_loss: 0.6706, g_loss: 1.9414, D(x): 0.78, D(G(z)): 0.21
# Epoch [60/300], Step [600/600], d_loss: 0.5574, g_loss: 2.5061, D(x): 0.81, D(G(z)): 0.19
# Saving fake_images-0061.png
# Epoch [61/300], Step [200/600], d_loss: 0.6900, g_loss: 1.5686, D(x): 0.81, D(G(z)): 0.29
# Epoch [61/300], Step [400/600], d_loss: 0.7406, g_loss: 1.5569, D(x): 0.77, D(G(z)): 0.25
# Epoch [61/300], Step [600/600], d_loss: 0.6927, g_loss: 2.6546, D(x): 0.73, D(G(z)): 0.14
# Saving fake_images-0062.png
# Epoch [62/300], Step [200/600], d_loss: 0.7184, g_loss: 2.4822, D(x): 0.77, D(G(z)): 0.24
# Epoch [62/300], Step [400/600], d_loss: 0.7194, g_loss: 1.8901, D(x): 0.76, D(G(z)): 0.24
# Epoch [62/300], Step [600/600], d_loss: 0.6268, g_loss: 1.8183, D(x): 0.79, D(G(z)): 0.23
# Saving fake_images-0063.png
# Epoch [63/300], Step [200/600], d_loss: 0.9967, g_loss: 1.5531, D(x): 0.76, D(G(z)): 0.35
# Epoch [63/300], Step [400/600], d_loss: 0.7299, g_loss: 2.2293, D(x): 0.82, D(G(z)): 0.28
# Epoch [63/300], Step [600/600], d_loss: 0.8884, g_loss: 1.8435, D(x): 0.72, D(G(z)): 0.30
# Saving fake_images-0064.png
# Epoch [64/300], Step [200/600], d_loss: 0.8107, g_loss: 1.7436, D(x): 0.74, D(G(z)): 0.29
# Epoch [64/300], Step [400/600], d_loss: 0.7318, g_loss: 2.1856, D(x): 0.74, D(G(z)): 0.19
# Epoch [64/300], Step [600/600], d_loss: 0.8166, g_loss: 1.6937, D(x): 0.72, D(G(z)): 0.24
# Saving fake_images-0065.png
# Epoch [65/300], Step [200/600], d_loss: 1.0953, g_loss: 1.8677, D(x): 0.64, D(G(z)): 0.29
# Epoch [65/300], Step [400/600], d_loss: 0.8669, g_loss: 1.7980, D(x): 0.82, D(G(z)): 0.35
# Epoch [65/300], Step [600/600], d_loss: 0.9123, g_loss: 1.5088, D(x): 0.74, D(G(z)): 0.32
# Saving fake_images-0066.png
# Epoch [66/300], Step [200/600], d_loss: 0.6128, g_loss: 2.0272, D(x): 0.87, D(G(z)): 0.30
# Epoch [66/300], Step [400/600], d_loss: 0.7298, g_loss: 1.6198, D(x): 0.77, D(G(z)): 0.26
# Epoch [66/300], Step [600/600], d_loss: 0.5796, g_loss: 1.6483, D(x): 0.85, D(G(z)): 0.27
# Saving fake_images-0067.png
# Epoch [67/300], Step [200/600], d_loss: 0.9411, g_loss: 1.6650, D(x): 0.66, D(G(z)): 0.24
# Epoch [67/300], Step [400/600], d_loss: 0.6689, g_loss: 2.1013, D(x): 0.76, D(G(z)): 0.22
# Epoch [67/300], Step [600/600], d_loss: 0.8067, g_loss: 1.8761, D(x): 0.74, D(G(z)): 0.27
# Saving fake_images-0068.png
# Epoch [68/300], Step [200/600], d_loss: 0.8307, g_loss: 1.5524, D(x): 0.75, D(G(z)): 0.29
# Epoch [68/300], Step [400/600], d_loss: 0.8624, g_loss: 1.7162, D(x): 0.69, D(G(z)): 0.25
# Epoch [68/300], Step [600/600], d_loss: 0.7887, g_loss: 1.6296, D(x): 0.77, D(G(z)): 0.28
# Saving fake_images-0069.png
# Epoch [69/300], Step [200/600], d_loss: 0.5625, g_loss: 2.0647, D(x): 0.87, D(G(z)): 0.25
# Epoch [69/300], Step [400/600], d_loss: 0.8972, g_loss: 2.1526, D(x): 0.76, D(G(z)): 0.28
# Epoch [69/300], Step [600/600], d_loss: 0.9114, g_loss: 1.7963, D(x): 0.69, D(G(z)): 0.26
# Saving fake_images-0070.png
# Epoch [70/300], Step [200/600], d_loss: 0.9512, g_loss: 2.0379, D(x): 0.71, D(G(z)): 0.28
# Epoch [70/300], Step [400/600], d_loss: 0.8216, g_loss: 1.3825, D(x): 0.69, D(G(z)): 0.24
# Epoch [70/300], Step [600/600], d_loss: 0.7710, g_loss: 1.8648, D(x): 0.75, D(G(z)): 0.25
# Saving fake_images-0071.png
# Epoch [71/300], Step [200/600], d_loss: 0.8602, g_loss: 1.7756, D(x): 0.76, D(G(z)): 0.30
# Epoch [71/300], Step [400/600], d_loss: 0.7862, g_loss: 2.1830, D(x): 0.72, D(G(z)): 0.24
# Epoch [71/300], Step [600/600], d_loss: 0.8399, g_loss: 1.4790, D(x): 0.71, D(G(z)): 0.27
# Saving fake_images-0072.png
# Epoch [72/300], Step [200/600], d_loss: 0.9126, g_loss: 1.4272, D(x): 0.76, D(G(z)): 0.33
# Epoch [72/300], Step [400/600], d_loss: 1.0021, g_loss: 1.3083, D(x): 0.68, D(G(z)): 0.33
# Epoch [72/300], Step [600/600], d_loss: 0.6861, g_loss: 1.8194, D(x): 0.79, D(G(z)): 0.26
# Saving fake_images-0073.png
# Epoch [73/300], Step [200/600], d_loss: 0.8206, g_loss: 1.9574, D(x): 0.77, D(G(z)): 0.31
# Epoch [73/300], Step [400/600], d_loss: 0.5315, g_loss: 2.4363, D(x): 0.81, D(G(z)): 0.18
# Epoch [73/300], Step [600/600], d_loss: 0.8630, g_loss: 1.6862, D(x): 0.71, D(G(z)): 0.28
# Saving fake_images-0074.png
# Epoch [74/300], Step [200/600], d_loss: 0.7257, g_loss: 2.1103, D(x): 0.79, D(G(z)): 0.30
# Epoch [74/300], Step [400/600], d_loss: 0.8842, g_loss: 1.8946, D(x): 0.72, D(G(z)): 0.27
# Epoch [74/300], Step [600/600], d_loss: 0.7388, g_loss: 1.8339, D(x): 0.74, D(G(z)): 0.22
# Saving fake_images-0075.png
# Epoch [75/300], Step [200/600], d_loss: 0.9935, g_loss: 1.6194, D(x): 0.77, D(G(z)): 0.32
# Epoch [75/300], Step [400/600], d_loss: 0.8005, g_loss: 2.2711, D(x): 0.69, D(G(z)): 0.18
# Epoch [75/300], Step [600/600], d_loss: 0.6964, g_loss: 1.9644, D(x): 0.75, D(G(z)): 0.24
# Saving fake_images-0076.png
# Epoch [76/300], Step [200/600], d_loss: 0.7169, g_loss: 1.6556, D(x): 0.74, D(G(z)): 0.25
# Epoch [76/300], Step [400/600], d_loss: 0.7918, g_loss: 1.7567, D(x): 0.76, D(G(z)): 0.30
# Epoch [76/300], Step [600/600], d_loss: 0.7435, g_loss: 1.5364, D(x): 0.77, D(G(z)): 0.26
# Saving fake_images-0077.png
# Epoch [77/300], Step [200/600], d_loss: 0.8345, g_loss: 1.7550, D(x): 0.68, D(G(z)): 0.20
# Epoch [77/300], Step [400/600], d_loss: 0.8155, g_loss: 1.4752, D(x): 0.76, D(G(z)): 0.29
# Epoch [77/300], Step [600/600], d_loss: 0.7393, g_loss: 1.8480, D(x): 0.74, D(G(z)): 0.25
# Saving fake_images-0078.png
# Epoch [78/300], Step [200/600], d_loss: 0.9843, g_loss: 1.6022, D(x): 0.72, D(G(z)): 0.30
# Epoch [78/300], Step [400/600], d_loss: 1.0248, g_loss: 1.7091, D(x): 0.70, D(G(z)): 0.34
# Epoch [78/300], Step [600/600], d_loss: 1.0166, g_loss: 1.3122, D(x): 0.75, D(G(z)): 0.39
# Saving fake_images-0079.png
# Epoch [79/300], Step [200/600], d_loss: 0.9319, g_loss: 1.6675, D(x): 0.72, D(G(z)): 0.31
# Epoch [79/300], Step [400/600], d_loss: 1.0314, g_loss: 1.4993, D(x): 0.68, D(G(z)): 0.33
# Epoch [79/300], Step [600/600], d_loss: 0.7298, g_loss: 1.7040, D(x): 0.75, D(G(z)): 0.24
# Saving fake_images-0080.png
# Epoch [80/300], Step [200/600], d_loss: 0.7350, g_loss: 1.7023, D(x): 0.75, D(G(z)): 0.26
# Epoch [80/300], Step [400/600], d_loss: 1.1394, g_loss: 1.6330, D(x): 0.67, D(G(z)): 0.36
# Epoch [80/300], Step [600/600], d_loss: 0.7433, g_loss: 2.0384, D(x): 0.74, D(G(z)): 0.24
# Saving fake_images-0081.png
# Epoch [81/300], Step [200/600], d_loss: 0.8746, g_loss: 2.0675, D(x): 0.67, D(G(z)): 0.23
# Epoch [81/300], Step [400/600], d_loss: 0.8526, g_loss: 1.9900, D(x): 0.72, D(G(z)): 0.26
# Epoch [81/300], Step [600/600], d_loss: 1.1033, g_loss: 1.4107, D(x): 0.68, D(G(z)): 0.37
# Saving fake_images-0082.png
# Epoch [82/300], Step [200/600], d_loss: 0.9897, g_loss: 1.6944, D(x): 0.64, D(G(z)): 0.26
# Epoch [82/300], Step [400/600], d_loss: 0.9126, g_loss: 1.6609, D(x): 0.74, D(G(z)): 0.34
# Epoch [82/300], Step [600/600], d_loss: 0.6168, g_loss: 1.7708, D(x): 0.84, D(G(z)): 0.29
# Saving fake_images-0083.png
# Epoch [83/300], Step [200/600], d_loss: 1.0353, g_loss: 1.8131, D(x): 0.69, D(G(z)): 0.28
# Epoch [83/300], Step [400/600], d_loss: 0.8974, g_loss: 1.4363, D(x): 0.79, D(G(z)): 0.38
# Epoch [83/300], Step [600/600], d_loss: 0.7549, g_loss: 2.0864, D(x): 0.77, D(G(z)): 0.25
# Saving fake_images-0084.png
# Epoch [84/300], Step [200/600], d_loss: 0.7379, g_loss: 2.0162, D(x): 0.76, D(G(z)): 0.26
# Epoch [84/300], Step [400/600], d_loss: 0.7515, g_loss: 1.5554, D(x): 0.70, D(G(z)): 0.20
# Epoch [84/300], Step [600/600], d_loss: 0.8415, g_loss: 1.8050, D(x): 0.75, D(G(z)): 0.30
# Saving fake_images-0085.png
# Epoch [85/300], Step [200/600], d_loss: 0.9761, g_loss: 1.8078, D(x): 0.72, D(G(z)): 0.32
# Epoch [85/300], Step [400/600], d_loss: 0.7712, g_loss: 1.5596, D(x): 0.82, D(G(z)): 0.33
# Epoch [85/300], Step [600/600], d_loss: 0.8572, g_loss: 1.7781, D(x): 0.72, D(G(z)): 0.30
# Saving fake_images-0086.png
# Epoch [86/300], Step [200/600], d_loss: 0.5922, g_loss: 2.1904, D(x): 0.77, D(G(z)): 0.21
# Epoch [86/300], Step [400/600], d_loss: 0.9661, g_loss: 1.4483, D(x): 0.72, D(G(z)): 0.31
# Epoch [86/300], Step [600/600], d_loss: 0.9708, g_loss: 1.8917, D(x): 0.71, D(G(z)): 0.31
# Saving fake_images-0087.png
# Epoch [87/300], Step [200/600], d_loss: 0.8126, g_loss: 1.8481, D(x): 0.75, D(G(z)): 0.26
# Epoch [87/300], Step [400/600], d_loss: 0.9289, g_loss: 1.8565, D(x): 0.66, D(G(z)): 0.27
# Epoch [87/300], Step [600/600], d_loss: 0.8757, g_loss: 1.7213, D(x): 0.73, D(G(z)): 0.31
# Saving fake_images-0088.png
# Epoch [88/300], Step [200/600], d_loss: 0.9507, g_loss: 1.7792, D(x): 0.65, D(G(z)): 0.26
# Epoch [88/300], Step [400/600], d_loss: 1.2343, g_loss: 1.5840, D(x): 0.72, D(G(z)): 0.42
# Epoch [88/300], Step [600/600], d_loss: 0.7860, g_loss: 1.5691, D(x): 0.74, D(G(z)): 0.27
# Saving fake_images-0089.png
# Epoch [89/300], Step [200/600], d_loss: 0.7339, g_loss: 1.5372, D(x): 0.76, D(G(z)): 0.25
# Epoch [89/300], Step [400/600], d_loss: 0.9380, g_loss: 1.8558, D(x): 0.72, D(G(z)): 0.33
# Epoch [89/300], Step [600/600], d_loss: 0.8335, g_loss: 2.1235, D(x): 0.71, D(G(z)): 0.21
# Saving fake_images-0090.png
# Epoch [90/300], Step [200/600], d_loss: 0.8472, g_loss: 1.6785, D(x): 0.72, D(G(z)): 0.26
# Epoch [90/300], Step [400/600], d_loss: 0.7801, g_loss: 1.8612, D(x): 0.76, D(G(z)): 0.28
# Epoch [90/300], Step [600/600], d_loss: 0.8637, g_loss: 1.5897, D(x): 0.73, D(G(z)): 0.27
# Saving fake_images-0091.png
# Epoch [91/300], Step [200/600], d_loss: 0.6134, g_loss: 1.7582, D(x): 0.80, D(G(z)): 0.23
# Epoch [91/300], Step [400/600], d_loss: 0.7203, g_loss: 1.7285, D(x): 0.74, D(G(z)): 0.24
# Epoch [91/300], Step [600/600], d_loss: 1.0224, g_loss: 1.4077, D(x): 0.64, D(G(z)): 0.30
# Saving fake_images-0092.png
# Epoch [92/300], Step [200/600], d_loss: 0.8096, g_loss: 1.6809, D(x): 0.81, D(G(z)): 0.33
# Epoch [92/300], Step [400/600], d_loss: 0.7797, g_loss: 1.3517, D(x): 0.74, D(G(z)): 0.29
# Epoch [92/300], Step [600/600], d_loss: 0.9683, g_loss: 1.5260, D(x): 0.74, D(G(z)): 0.37
# Saving fake_images-0093.png
# Epoch [93/300], Step [200/600], d_loss: 0.8989, g_loss: 1.4404, D(x): 0.71, D(G(z)): 0.30
# Epoch [93/300], Step [400/600], d_loss: 0.7658, g_loss: 1.4153, D(x): 0.77, D(G(z)): 0.29
# Epoch [93/300], Step [600/600], d_loss: 0.8613, g_loss: 1.7304, D(x): 0.67, D(G(z)): 0.24
# Saving fake_images-0094.png
# Epoch [94/300], Step [200/600], d_loss: 1.0522, g_loss: 1.6071, D(x): 0.68, D(G(z)): 0.32
# Epoch [94/300], Step [400/600], d_loss: 1.1004, g_loss: 1.2457, D(x): 0.62, D(G(z)): 0.32
# Epoch [94/300], Step [600/600], d_loss: 0.8545, g_loss: 1.4456, D(x): 0.77, D(G(z)): 0.32
# Saving fake_images-0095.png
# Epoch [95/300], Step [200/600], d_loss: 1.1066, g_loss: 1.3801, D(x): 0.66, D(G(z)): 0.31
# Epoch [95/300], Step [400/600], d_loss: 1.0208, g_loss: 1.1546, D(x): 0.62, D(G(z)): 0.28
# Epoch [95/300], Step [600/600], d_loss: 0.9278, g_loss: 1.3822, D(x): 0.68, D(G(z)): 0.30
# Saving fake_images-0096.png
# Epoch [96/300], Step [200/600], d_loss: 0.8979, g_loss: 1.7905, D(x): 0.73, D(G(z)): 0.30
# Epoch [96/300], Step [400/600], d_loss: 0.7510, g_loss: 1.6084, D(x): 0.73, D(G(z)): 0.25
# Epoch [96/300], Step [600/600], d_loss: 0.9815, g_loss: 1.8197, D(x): 0.66, D(G(z)): 0.28
# Saving fake_images-0097.png
# Epoch [97/300], Step [200/600], d_loss: 0.9239, g_loss: 1.5512, D(x): 0.70, D(G(z)): 0.32
# Epoch [97/300], Step [400/600], d_loss: 0.8911, g_loss: 1.4157, D(x): 0.73, D(G(z)): 0.34
# Epoch [97/300], Step [600/600], d_loss: 1.0356, g_loss: 1.7169, D(x): 0.65, D(G(z)): 0.31
# Saving fake_images-0098.png
# Epoch [98/300], Step [200/600], d_loss: 0.8175, g_loss: 1.4057, D(x): 0.74, D(G(z)): 0.32
# Epoch [98/300], Step [400/600], d_loss: 0.9285, g_loss: 1.6807, D(x): 0.63, D(G(z)): 0.24
# Epoch [98/300], Step [600/600], d_loss: 0.8521, g_loss: 1.6663, D(x): 0.74, D(G(z)): 0.29
# Saving fake_images-0099.png
# Epoch [99/300], Step [200/600], d_loss: 0.8276, g_loss: 1.6489, D(x): 0.72, D(G(z)): 0.28
# Epoch [99/300], Step [400/600], d_loss: 0.9427, g_loss: 1.3584, D(x): 0.71, D(G(z)): 0.33
# Epoch [99/300], Step [600/600], d_loss: 0.6732, g_loss: 1.9515, D(x): 0.74, D(G(z)): 0.22
# Saving fake_images-0100.png
# Epoch [100/300], Step [200/600], d_loss: 1.0003, g_loss: 1.6452, D(x): 0.59, D(G(z)): 0.24
# Epoch [100/300], Step [400/600], d_loss: 0.9366, g_loss: 1.5966, D(x): 0.74, D(G(z)): 0.36
# Epoch [100/300], Step [600/600], d_loss: 0.9455, g_loss: 1.1507, D(x): 0.74, D(G(z)): 0.37
# Saving fake_images-0101.png
# Epoch [101/300], Step [200/600], d_loss: 0.7634, g_loss: 1.6528, D(x): 0.74, D(G(z)): 0.27
# Epoch [101/300], Step [400/600], d_loss: 0.8542, g_loss: 1.8788, D(x): 0.68, D(G(z)): 0.26
# Epoch [101/300], Step [600/600], d_loss: 0.7865, g_loss: 1.5810, D(x): 0.71, D(G(z)): 0.25
# Saving fake_images-0102.png
# Epoch [102/300], Step [200/600], d_loss: 1.0198, g_loss: 1.3998, D(x): 0.69, D(G(z)): 0.33
# Epoch [102/300], Step [400/600], d_loss: 0.9080, g_loss: 1.8979, D(x): 0.69, D(G(z)): 0.26
# Epoch [102/300], Step [600/600], d_loss: 1.0040, g_loss: 1.4209, D(x): 0.69, D(G(z)): 0.33
# Saving fake_images-0103.png
# Epoch [103/300], Step [200/600], d_loss: 0.9414, g_loss: 1.8110, D(x): 0.68, D(G(z)): 0.29
# Epoch [103/300], Step [400/600], d_loss: 0.9432, g_loss: 1.4785, D(x): 0.70, D(G(z)): 0.33
# Epoch [103/300], Step [600/600], d_loss: 1.0551, g_loss: 1.6207, D(x): 0.73, D(G(z)): 0.37
# Saving fake_images-0104.png
# Epoch [104/300], Step [200/600], d_loss: 0.9900, g_loss: 1.5039, D(x): 0.68, D(G(z)): 0.34
# Epoch [104/300], Step [400/600], d_loss: 0.9088, g_loss: 1.6512, D(x): 0.67, D(G(z)): 0.28
# Epoch [104/300], Step [600/600], d_loss: 0.7036, g_loss: 1.3381, D(x): 0.79, D(G(z)): 0.29
# Saving fake_images-0105.png
# Epoch [105/300], Step [200/600], d_loss: 1.0857, g_loss: 1.1748, D(x): 0.70, D(G(z)): 0.38
# Epoch [105/300], Step [400/600], d_loss: 0.9528, g_loss: 1.5944, D(x): 0.73, D(G(z)): 0.36
# Epoch [105/300], Step [600/600], d_loss: 0.8836, g_loss: 1.5454, D(x): 0.71, D(G(z)): 0.29
# Saving fake_images-0106.png
# Epoch [106/300], Step [200/600], d_loss: 1.0069, g_loss: 1.7031, D(x): 0.65, D(G(z)): 0.31
# Epoch [106/300], Step [400/600], d_loss: 0.9005, g_loss: 1.7538, D(x): 0.74, D(G(z)): 0.30
# Epoch [106/300], Step [600/600], d_loss: 1.0159, g_loss: 1.5970, D(x): 0.65, D(G(z)): 0.33
# Saving fake_images-0107.png
# Epoch [107/300], Step [200/600], d_loss: 0.9810, g_loss: 1.6045, D(x): 0.69, D(G(z)): 0.31
# Epoch [107/300], Step [400/600], d_loss: 0.8936, g_loss: 1.5453, D(x): 0.74, D(G(z)): 0.35
# Epoch [107/300], Step [600/600], d_loss: 1.1289, g_loss: 1.2398, D(x): 0.63, D(G(z)): 0.29
# Saving fake_images-0108.png
# Epoch [108/300], Step [200/600], d_loss: 1.1197, g_loss: 1.4196, D(x): 0.65, D(G(z)): 0.36
# Epoch [108/300], Step [400/600], d_loss: 0.8335, g_loss: 1.5722, D(x): 0.71, D(G(z)): 0.27
# Epoch [108/300], Step [600/600], d_loss: 0.9914, g_loss: 1.2668, D(x): 0.70, D(G(z)): 0.35
# Saving fake_images-0109.png
# Epoch [109/300], Step [200/600], d_loss: 0.8434, g_loss: 1.7504, D(x): 0.69, D(G(z)): 0.26
# Epoch [109/300], Step [400/600], d_loss: 0.8009, g_loss: 1.5056, D(x): 0.76, D(G(z)): 0.31
# Epoch [109/300], Step [600/600], d_loss: 0.9348, g_loss: 1.2960, D(x): 0.67, D(G(z)): 0.34
# Saving fake_images-0110.png
# Epoch [110/300], Step [200/600], d_loss: 0.9857, g_loss: 1.6583, D(x): 0.65, D(G(z)): 0.32
# Epoch [110/300], Step [400/600], d_loss: 0.9265, g_loss: 1.3294, D(x): 0.71, D(G(z)): 0.33
# Epoch [110/300], Step [600/600], d_loss: 0.7810, g_loss: 1.3899, D(x): 0.72, D(G(z)): 0.27
# Saving fake_images-0111.png
# Epoch [111/300], Step [200/600], d_loss: 0.9499, g_loss: 1.4764, D(x): 0.66, D(G(z)): 0.26
# Epoch [111/300], Step [400/600], d_loss: 0.9637, g_loss: 1.5196, D(x): 0.66, D(G(z)): 0.28
# Epoch [111/300], Step [600/600], d_loss: 0.9841, g_loss: 1.3595, D(x): 0.68, D(G(z)): 0.33
# Saving fake_images-0112.png
# Epoch [112/300], Step [200/600], d_loss: 0.9720, g_loss: 1.5621, D(x): 0.70, D(G(z)): 0.34
# Epoch [112/300], Step [400/600], d_loss: 0.8017, g_loss: 1.6329, D(x): 0.70, D(G(z)): 0.23
# Epoch [112/300], Step [600/600], d_loss: 0.9148, g_loss: 1.5225, D(x): 0.75, D(G(z)): 0.37
# Saving fake_images-0113.png
# Epoch [113/300], Step [200/600], d_loss: 0.9712, g_loss: 1.5231, D(x): 0.71, D(G(z)): 0.32
# Epoch [113/300], Step [400/600], d_loss: 1.0835, g_loss: 1.2263, D(x): 0.71, D(G(z)): 0.40
# Epoch [113/300], Step [600/600], d_loss: 0.9205, g_loss: 1.7599, D(x): 0.64, D(G(z)): 0.24
# Saving fake_images-0114.png
# Epoch [114/300], Step [200/600], d_loss: 0.9469, g_loss: 1.6276, D(x): 0.63, D(G(z)): 0.25
# Epoch [114/300], Step [400/600], d_loss: 0.8922, g_loss: 2.0450, D(x): 0.67, D(G(z)): 0.26
# Epoch [114/300], Step [600/600], d_loss: 0.8615, g_loss: 1.5831, D(x): 0.69, D(G(z)): 0.26
# Saving fake_images-0115.png
# Epoch [115/300], Step [200/600], d_loss: 0.7889, g_loss: 1.6909, D(x): 0.73, D(G(z)): 0.31
# Epoch [115/300], Step [400/600], d_loss: 1.1281, g_loss: 1.4067, D(x): 0.65, D(G(z)): 0.37
# Epoch [115/300], Step [600/600], d_loss: 1.0688, g_loss: 1.4719, D(x): 0.65, D(G(z)): 0.33
# Saving fake_images-0116.png
# Epoch [116/300], Step [200/600], d_loss: 1.0836, g_loss: 1.6189, D(x): 0.64, D(G(z)): 0.32
# Epoch [116/300], Step [400/600], d_loss: 0.8068, g_loss: 1.6924, D(x): 0.71, D(G(z)): 0.25
# Epoch [116/300], Step [600/600], d_loss: 0.8056, g_loss: 1.8402, D(x): 0.73, D(G(z)): 0.28
# Saving fake_images-0117.png
# Epoch [117/300], Step [200/600], d_loss: 1.0547, g_loss: 1.6930, D(x): 0.65, D(G(z)): 0.32
# Epoch [117/300], Step [400/600], d_loss: 0.8088, g_loss: 1.6589, D(x): 0.70, D(G(z)): 0.27
# Epoch [117/300], Step [600/600], d_loss: 0.9813, g_loss: 1.7291, D(x): 0.71, D(G(z)): 0.32
# Saving fake_images-0118.png
# Epoch [118/300], Step [200/600], d_loss: 0.8492, g_loss: 1.3460, D(x): 0.71, D(G(z)): 0.31
# Epoch [118/300], Step [400/600], d_loss: 0.8822, g_loss: 1.4020, D(x): 0.69, D(G(z)): 0.31
# Epoch [118/300], Step [600/600], d_loss: 1.0033, g_loss: 1.4034, D(x): 0.66, D(G(z)): 0.30
# Saving fake_images-0119.png
# Epoch [119/300], Step [200/600], d_loss: 1.0113, g_loss: 1.6171, D(x): 0.63, D(G(z)): 0.28
# Epoch [119/300], Step [400/600], d_loss: 0.9091, g_loss: 1.2772, D(x): 0.70, D(G(z)): 0.32
# Epoch [119/300], Step [600/600], d_loss: 0.9615, g_loss: 1.3284, D(x): 0.74, D(G(z)): 0.34
# Saving fake_images-0120.png
# Epoch [120/300], Step [200/600], d_loss: 0.8978, g_loss: 1.6331, D(x): 0.78, D(G(z)): 0.34
# Epoch [120/300], Step [400/600], d_loss: 1.2485, g_loss: 1.1429, D(x): 0.60, D(G(z)): 0.37
# Epoch [120/300], Step [600/600], d_loss: 1.0668, g_loss: 1.5022, D(x): 0.62, D(G(z)): 0.29
# Saving fake_images-0121.png
# Epoch [121/300], Step [200/600], d_loss: 0.9348, g_loss: 1.8214, D(x): 0.67, D(G(z)): 0.27
# Epoch [121/300], Step [400/600], d_loss: 0.9306, g_loss: 1.7490, D(x): 0.64, D(G(z)): 0.26
# Epoch [121/300], Step [600/600], d_loss: 0.8791, g_loss: 1.5000, D(x): 0.71, D(G(z)): 0.30
# Saving fake_images-0122.png
# Epoch [122/300], Step [200/600], d_loss: 0.8761, g_loss: 1.7124, D(x): 0.72, D(G(z)): 0.29
# Epoch [122/300], Step [400/600], d_loss: 0.9016, g_loss: 1.7448, D(x): 0.63, D(G(z)): 0.22
# Epoch [122/300], Step [600/600], d_loss: 0.8911, g_loss: 1.6183, D(x): 0.69, D(G(z)): 0.28
# Saving fake_images-0123.png
# Epoch [123/300], Step [200/600], d_loss: 0.9433, g_loss: 1.3560, D(x): 0.67, D(G(z)): 0.30
# Epoch [123/300], Step [400/600], d_loss: 1.1656, g_loss: 1.5687, D(x): 0.65, D(G(z)): 0.37
# Epoch [123/300], Step [600/600], d_loss: 0.9078, g_loss: 1.3559, D(x): 0.73, D(G(z)): 0.34
# Saving fake_images-0124.png
# Epoch [124/300], Step [200/600], d_loss: 0.9946, g_loss: 1.2787, D(x): 0.69, D(G(z)): 0.37
# Epoch [124/300], Step [400/600], d_loss: 0.6866, g_loss: 1.5707, D(x): 0.77, D(G(z)): 0.26
# Epoch [124/300], Step [600/600], d_loss: 0.8985, g_loss: 1.5115, D(x): 0.68, D(G(z)): 0.26
# Saving fake_images-0125.png
# Epoch [125/300], Step [200/600], d_loss: 0.7906, g_loss: 1.4949, D(x): 0.75, D(G(z)): 0.29
# Epoch [125/300], Step [400/600], d_loss: 0.8547, g_loss: 1.5759, D(x): 0.74, D(G(z)): 0.32
# Epoch [125/300], Step [600/600], d_loss: 0.8948, g_loss: 1.4761, D(x): 0.68, D(G(z)): 0.30
# Saving fake_images-0126.png
# Epoch [126/300], Step [200/600], d_loss: 1.0230, g_loss: 1.5554, D(x): 0.72, D(G(z)): 0.37
# Epoch [126/300], Step [400/600], d_loss: 0.9764, g_loss: 1.6287, D(x): 0.68, D(G(z)): 0.31
# Epoch [126/300], Step [600/600], d_loss: 0.9829, g_loss: 1.2924, D(x): 0.66, D(G(z)): 0.30
# Saving fake_images-0127.png
# Epoch [127/300], Step [200/600], d_loss: 0.8870, g_loss: 1.3248, D(x): 0.76, D(G(z)): 0.35
# Epoch [127/300], Step [400/600], d_loss: 1.0379, g_loss: 1.4982, D(x): 0.66, D(G(z)): 0.34
# Epoch [127/300], Step [600/600], d_loss: 1.3340, g_loss: 1.2568, D(x): 0.62, D(G(z)): 0.42
# Saving fake_images-0128.png
# Epoch [128/300], Step [200/600], d_loss: 0.9843, g_loss: 1.2499, D(x): 0.71, D(G(z)): 0.37
# Epoch [128/300], Step [400/600], d_loss: 1.0949, g_loss: 1.4310, D(x): 0.65, D(G(z)): 0.35
# Epoch [128/300], Step [600/600], d_loss: 1.1962, g_loss: 1.3149, D(x): 0.66, D(G(z)): 0.42
# Saving fake_images-0129.png
# Epoch [129/300], Step [200/600], d_loss: 0.9715, g_loss: 1.4611, D(x): 0.72, D(G(z)): 0.36
# Epoch [129/300], Step [400/600], d_loss: 0.9705, g_loss: 1.6968, D(x): 0.72, D(G(z)): 0.33
# Epoch [129/300], Step [600/600], d_loss: 0.9877, g_loss: 1.5626, D(x): 0.67, D(G(z)): 0.31
# Saving fake_images-0130.png
# Epoch [130/300], Step [200/600], d_loss: 0.8927, g_loss: 1.7290, D(x): 0.68, D(G(z)): 0.29
# Epoch [130/300], Step [400/600], d_loss: 0.9240, g_loss: 1.4654, D(x): 0.68, D(G(z)): 0.30
# Epoch [130/300], Step [600/600], d_loss: 1.0909, g_loss: 1.7503, D(x): 0.65, D(G(z)): 0.34
# Saving fake_images-0131.png
# Epoch [131/300], Step [200/600], d_loss: 0.8731, g_loss: 1.4473, D(x): 0.73, D(G(z)): 0.31
# Epoch [131/300], Step [400/600], d_loss: 0.8811, g_loss: 1.8185, D(x): 0.71, D(G(z)): 0.30
# Epoch [131/300], Step [600/600], d_loss: 1.0094, g_loss: 1.3926, D(x): 0.67, D(G(z)): 0.33
# Saving fake_images-0132.png
# Epoch [132/300], Step [200/600], d_loss: 1.0656, g_loss: 1.4153, D(x): 0.70, D(G(z)): 0.36
# Epoch [132/300], Step [400/600], d_loss: 1.0567, g_loss: 1.5756, D(x): 0.57, D(G(z)): 0.25
# Epoch [132/300], Step [600/600], d_loss: 0.9863, g_loss: 1.4665, D(x): 0.69, D(G(z)): 0.34
# Saving fake_images-0133.png
# Epoch [133/300], Step [200/600], d_loss: 0.8853, g_loss: 1.8064, D(x): 0.71, D(G(z)): 0.31
# Epoch [133/300], Step [400/600], d_loss: 0.8333, g_loss: 1.3058, D(x): 0.76, D(G(z)): 0.33
# Epoch [133/300], Step [600/600], d_loss: 0.8141, g_loss: 1.5836, D(x): 0.70, D(G(z)): 0.28
# Saving fake_images-0134.png
# Epoch [134/300], Step [200/600], d_loss: 0.8041, g_loss: 1.9270, D(x): 0.70, D(G(z)): 0.25
# Epoch [134/300], Step [400/600], d_loss: 0.9587, g_loss: 1.5310, D(x): 0.64, D(G(z)): 0.29
# Epoch [134/300], Step [600/600], d_loss: 0.8597, g_loss: 1.3241, D(x): 0.67, D(G(z)): 0.28
# Saving fake_images-0135.png
# Epoch [135/300], Step [200/600], d_loss: 1.0884, g_loss: 1.6093, D(x): 0.63, D(G(z)): 0.30
# Epoch [135/300], Step [400/600], d_loss: 0.9064, g_loss: 1.4931, D(x): 0.70, D(G(z)): 0.31
# Epoch [135/300], Step [600/600], d_loss: 1.0175, g_loss: 1.4012, D(x): 0.71, D(G(z)): 0.36
# Saving fake_images-0136.png
# Epoch [136/300], Step [200/600], d_loss: 0.9102, g_loss: 1.3546, D(x): 0.70, D(G(z)): 0.32
# Epoch [136/300], Step [400/600], d_loss: 0.8905, g_loss: 1.5426, D(x): 0.67, D(G(z)): 0.27
# Epoch [136/300], Step [600/600], d_loss: 1.0044, g_loss: 1.4233, D(x): 0.67, D(G(z)): 0.33
# Saving fake_images-0137.png
# Epoch [137/300], Step [200/600], d_loss: 0.9507, g_loss: 1.6434, D(x): 0.70, D(G(z)): 0.36
# Epoch [137/300], Step [400/600], d_loss: 0.9659, g_loss: 1.4409, D(x): 0.72, D(G(z)): 0.34
# Epoch [137/300], Step [600/600], d_loss: 0.9518, g_loss: 1.3021, D(x): 0.70, D(G(z)): 0.35
# Saving fake_images-0138.png
# Epoch [138/300], Step [200/600], d_loss: 1.0224, g_loss: 1.4957, D(x): 0.66, D(G(z)): 0.32
# Epoch [138/300], Step [400/600], d_loss: 0.8936, g_loss: 1.7151, D(x): 0.67, D(G(z)): 0.26
# Epoch [138/300], Step [600/600], d_loss: 0.8526, g_loss: 1.6358, D(x): 0.66, D(G(z)): 0.24
# Saving fake_images-0139.png
# Epoch [139/300], Step [200/600], d_loss: 0.8467, g_loss: 1.4926, D(x): 0.68, D(G(z)): 0.27
# Epoch [139/300], Step [400/600], d_loss: 1.1044, g_loss: 1.4322, D(x): 0.69, D(G(z)): 0.37
# Epoch [139/300], Step [600/600], d_loss: 0.9236, g_loss: 1.6538, D(x): 0.70, D(G(z)): 0.30
# Saving fake_images-0140.png
# Epoch [140/300], Step [200/600], d_loss: 0.8921, g_loss: 1.8241, D(x): 0.62, D(G(z)): 0.23
# Epoch [140/300], Step [400/600], d_loss: 0.8861, g_loss: 1.5615, D(x): 0.75, D(G(z)): 0.33
# Epoch [140/300], Step [600/600], d_loss: 1.1024, g_loss: 1.3776, D(x): 0.67, D(G(z)): 0.36
# Saving fake_images-0141.png
# Epoch [141/300], Step [200/600], d_loss: 0.9195, g_loss: 1.3799, D(x): 0.69, D(G(z)): 0.31
# Epoch [141/300], Step [400/600], d_loss: 1.1049, g_loss: 1.3181, D(x): 0.72, D(G(z)): 0.41
# Epoch [141/300], Step [600/600], d_loss: 0.9123, g_loss: 1.6450, D(x): 0.62, D(G(z)): 0.21
# Saving fake_images-0142.png
# Epoch [142/300], Step [200/600], d_loss: 0.9689, g_loss: 1.6290, D(x): 0.67, D(G(z)): 0.29
# Epoch [142/300], Step [400/600], d_loss: 0.9537, g_loss: 1.7869, D(x): 0.65, D(G(z)): 0.29
# Epoch [142/300], Step [600/600], d_loss: 0.9269, g_loss: 1.2395, D(x): 0.64, D(G(z)): 0.27
# Saving fake_images-0143.png
# Epoch [143/300], Step [200/600], d_loss: 0.9123, g_loss: 1.4242, D(x): 0.71, D(G(z)): 0.33
# Epoch [143/300], Step [400/600], d_loss: 0.9530, g_loss: 1.8896, D(x): 0.70, D(G(z)): 0.33
# Epoch [143/300], Step [600/600], d_loss: 0.9875, g_loss: 1.3465, D(x): 0.72, D(G(z)): 0.37
# Saving fake_images-0144.png
# Epoch [144/300], Step [200/600], d_loss: 0.9467, g_loss: 1.7101, D(x): 0.74, D(G(z)): 0.33
# Epoch [144/300], Step [400/600], d_loss: 0.8751, g_loss: 1.6107, D(x): 0.75, D(G(z)): 0.34
# Epoch [144/300], Step [600/600], d_loss: 1.0615, g_loss: 1.5025, D(x): 0.64, D(G(z)): 0.32
# Saving fake_images-0145.png
# Epoch [145/300], Step [200/600], d_loss: 0.9487, g_loss: 1.2379, D(x): 0.77, D(G(z)): 0.39
# Epoch [145/300], Step [400/600], d_loss: 0.9920, g_loss: 1.4992, D(x): 0.72, D(G(z)): 0.36
# Epoch [145/300], Step [600/600], d_loss: 0.7544, g_loss: 1.6520, D(x): 0.75, D(G(z)): 0.28
# Saving fake_images-0146.png
# Epoch [146/300], Step [200/600], d_loss: 0.9007, g_loss: 1.4572, D(x): 0.74, D(G(z)): 0.35
# Epoch [146/300], Step [400/600], d_loss: 0.8716, g_loss: 1.8844, D(x): 0.66, D(G(z)): 0.26
# Epoch [146/300], Step [600/600], d_loss: 0.9491, g_loss: 1.5750, D(x): 0.66, D(G(z)): 0.30
# Saving fake_images-0147.png
# Epoch [147/300], Step [200/600], d_loss: 1.0234, g_loss: 1.5985, D(x): 0.65, D(G(z)): 0.32
# Epoch [147/300], Step [400/600], d_loss: 0.9618, g_loss: 1.6197, D(x): 0.63, D(G(z)): 0.28
# Epoch [147/300], Step [600/600], d_loss: 0.9019, g_loss: 1.4612, D(x): 0.68, D(G(z)): 0.30
# Saving fake_images-0148.png
# Epoch [148/300], Step [200/600], d_loss: 0.7839, g_loss: 1.3935, D(x): 0.70, D(G(z)): 0.27
# Epoch [148/300], Step [400/600], d_loss: 0.8611, g_loss: 1.3653, D(x): 0.73, D(G(z)): 0.31
# Epoch [148/300], Step [600/600], d_loss: 0.8660, g_loss: 1.5004, D(x): 0.71, D(G(z)): 0.31
# Saving fake_images-0149.png
# Epoch [149/300], Step [200/600], d_loss: 0.9039, g_loss: 1.3459, D(x): 0.69, D(G(z)): 0.30
# Epoch [149/300], Step [400/600], d_loss: 0.9411, g_loss: 1.5665, D(x): 0.66, D(G(z)): 0.27
# Epoch [149/300], Step [600/600], d_loss: 1.0480, g_loss: 1.3916, D(x): 0.62, D(G(z)): 0.32
# Saving fake_images-0150.png
# Epoch [150/300], Step [200/600], d_loss: 1.0367, g_loss: 1.5919, D(x): 0.69, D(G(z)): 0.36
# Epoch [150/300], Step [400/600], d_loss: 1.0770, g_loss: 1.2508, D(x): 0.66, D(G(z)): 0.35
# Epoch [150/300], Step [600/600], d_loss: 1.1797, g_loss: 1.4987, D(x): 0.61, D(G(z)): 0.36
# Saving fake_images-0151.png
# Epoch [151/300], Step [200/600], d_loss: 1.0121, g_loss: 1.5746, D(x): 0.70, D(G(z)): 0.37
# Epoch [151/300], Step [400/600], d_loss: 0.9187, g_loss: 1.4542, D(x): 0.70, D(G(z)): 0.29
# Epoch [151/300], Step [600/600], d_loss: 1.1198, g_loss: 1.4489, D(x): 0.57, D(G(z)): 0.24
# Saving fake_images-0152.png
# Epoch [152/300], Step [200/600], d_loss: 0.9595, g_loss: 1.7257, D(x): 0.63, D(G(z)): 0.28
# Epoch [152/300], Step [400/600], d_loss: 0.8490, g_loss: 1.5264, D(x): 0.71, D(G(z)): 0.31
# Epoch [152/300], Step [600/600], d_loss: 0.9292, g_loss: 1.4029, D(x): 0.71, D(G(z)): 0.35
# Saving fake_images-0153.png
# Epoch [153/300], Step [200/600], d_loss: 1.0861, g_loss: 1.4961, D(x): 0.64, D(G(z)): 0.33
# Epoch [153/300], Step [400/600], d_loss: 0.7936, g_loss: 1.4081, D(x): 0.74, D(G(z)): 0.31
# Epoch [153/300], Step [600/600], d_loss: 1.0189, g_loss: 1.6199, D(x): 0.62, D(G(z)): 0.30
# Saving fake_images-0154.png
# Epoch [154/300], Step [200/600], d_loss: 0.9267, g_loss: 1.1779, D(x): 0.74, D(G(z)): 0.37
# Epoch [154/300], Step [400/600], d_loss: 0.9331, g_loss: 1.2667, D(x): 0.72, D(G(z)): 0.36
# Epoch [154/300], Step [600/600], d_loss: 0.9257, g_loss: 1.3276, D(x): 0.70, D(G(z)): 0.32
# Saving fake_images-0155.png
# Epoch [155/300], Step [200/600], d_loss: 0.8166, g_loss: 1.8902, D(x): 0.71, D(G(z)): 0.27
# Epoch [155/300], Step [400/600], d_loss: 0.9022, g_loss: 1.6283, D(x): 0.73, D(G(z)): 0.33
# Epoch [155/300], Step [600/600], d_loss: 0.9953, g_loss: 1.6355, D(x): 0.64, D(G(z)): 0.30
# Saving fake_images-0156.png
# Epoch [156/300], Step [200/600], d_loss: 0.8024, g_loss: 1.5163, D(x): 0.73, D(G(z)): 0.29
# Epoch [156/300], Step [400/600], d_loss: 1.0496, g_loss: 1.3615, D(x): 0.71, D(G(z)): 0.36
# Epoch [156/300], Step [600/600], d_loss: 1.0702, g_loss: 1.3530, D(x): 0.74, D(G(z)): 0.43
# Saving fake_images-0157.png
# Epoch [157/300], Step [200/600], d_loss: 0.8885, g_loss: 1.2647, D(x): 0.70, D(G(z)): 0.31
# Epoch [157/300], Step [400/600], d_loss: 0.8599, g_loss: 1.5475, D(x): 0.69, D(G(z)): 0.29
# Epoch [157/300], Step [600/600], d_loss: 0.9029, g_loss: 1.4543, D(x): 0.71, D(G(z)): 0.30
# Saving fake_images-0158.png
# Epoch [158/300], Step [200/600], d_loss: 1.0395, g_loss: 1.0491, D(x): 0.74, D(G(z)): 0.41
# Epoch [158/300], Step [400/600], d_loss: 0.8065, g_loss: 1.5520, D(x): 0.73, D(G(z)): 0.31
# Epoch [158/300], Step [600/600], d_loss: 0.8092, g_loss: 1.4627, D(x): 0.74, D(G(z)): 0.32
# Saving fake_images-0159.png
# Epoch [159/300], Step [200/600], d_loss: 0.8600, g_loss: 1.5898, D(x): 0.69, D(G(z)): 0.28
# Epoch [159/300], Step [400/600], d_loss: 0.8628, g_loss: 1.4493, D(x): 0.68, D(G(z)): 0.27
# Epoch [159/300], Step [600/600], d_loss: 0.9772, g_loss: 1.6380, D(x): 0.65, D(G(z)): 0.30
# Saving fake_images-0160.png
# Epoch [160/300], Step [200/600], d_loss: 0.9689, g_loss: 1.2195, D(x): 0.69, D(G(z)): 0.33
# ...
# Epoch [247/300], Step [200/600], d_loss: 0.7788, g_loss: 1.3182, D(x): 0.77, D(G(z)): 0.32
# Epoch [247/300], Step [400/600], d_loss: 0.9150, g_loss: 1.7332, D(x): 0.67, D(G(z)): 0.29
# Epoch [247/300], Step [600/600], d_loss: 0.9872, g_loss: 1.6222, D(x): 0.71, D(G(z)): 0.36
# Saving fake_images-0248.png
# Epoch [248/300], Step [200/600], d_loss: 0.9723, g_loss: 1.4459, D(x): 0.66, D(G(z)): 0.29
# Epoch [248/300], Step [400/600], d_loss: 0.8858, g_loss: 1.3453, D(x): 0.70, D(G(z)): 0.30
# Epoch [248/300], Step [600/600], d_loss: 0.7795, g_loss: 1.4069, D(x): 0.76, D(G(z)): 0.31
# Saving fake_images-0249.png
# Epoch [249/300], Step [200/600], d_loss: 0.9483, g_loss: 1.4199, D(x): 0.66, D(G(z)): 0.29
# Epoch [249/300], Step [400/600], d_loss: 1.0417, g_loss: 1.5984, D(x): 0.74, D(G(z)): 0.37
# Epoch [249/300], Step [600/600], d_loss: 1.0015, g_loss: 1.4001, D(x): 0.70, D(G(z)): 0.34
# Saving fake_images-0250.png
# Epoch [250/300], Step [200/600], d_loss: 0.9862, g_loss: 1.5252, D(x): 0.68, D(G(z)): 0.32
# Epoch [250/300], Step [400/600], d_loss: 0.9358, g_loss: 1.2671, D(x): 0.70, D(G(z)): 0.32
# Epoch [250/300], Step [600/600], d_loss: 1.0288, g_loss: 1.1938, D(x): 0.66, D(G(z)): 0.35
# Saving fake_images-0251.png
# Epoch [251/300], Step [200/600], d_loss: 1.0273, g_loss: 1.7050, D(x): 0.64, D(G(z)): 0.30
# Epoch [251/300], Step [400/600], d_loss: 0.8763, g_loss: 1.5532, D(x): 0.68, D(G(z)): 0.27
# Epoch [251/300], Step [600/600], d_loss: 0.9801, g_loss: 1.4752, D(x): 0.65, D(G(z)): 0.28
# Saving fake_images-0252.png
# Epoch [252/300], Step [200/600], d_loss: 0.9979, g_loss: 1.3888, D(x): 0.74, D(G(z)): 0.37
# Epoch [252/300], Step [400/600], d_loss: 0.8681, g_loss: 1.7954, D(x): 0.67, D(G(z)): 0.26
# Epoch [252/300], Step [600/600], d_loss: 0.9299, g_loss: 1.3838, D(x): 0.73, D(G(z)): 0.33
# Saving fake_images-0253.png
# Epoch [253/300], Step [200/600], d_loss: 0.8920, g_loss: 1.5481, D(x): 0.69, D(G(z)): 0.30
# Epoch [253/300], Step [400/600], d_loss: 0.8515, g_loss: 1.4880, D(x): 0.72, D(G(z)): 0.31
# Epoch [253/300], Step [600/600], d_loss: 0.8565, g_loss: 1.4512, D(x): 0.73, D(G(z)): 0.34
# Saving fake_images-0254.png
# Epoch [254/300], Step [200/600], d_loss: 0.8629, g_loss: 1.4076, D(x): 0.69, D(G(z)): 0.28
# Epoch [254/300], Step [400/600], d_loss: 0.9346, g_loss: 1.1796, D(x): 0.72, D(G(z)): 0.34
# Epoch [254/300], Step [600/600], d_loss: 0.9545, g_loss: 1.3483, D(x): 0.70, D(G(z)): 0.35
# Saving fake_images-0255.png
# Epoch [255/300], Step [200/600], d_loss: 0.8205, g_loss: 1.5305, D(x): 0.73, D(G(z)): 0.30
# Epoch [255/300], Step [400/600], d_loss: 0.8401, g_loss: 1.4254, D(x): 0.72, D(G(z)): 0.30
# Epoch [255/300], Step [600/600], d_loss: 0.9131, g_loss: 1.5286, D(x): 0.72, D(G(z)): 0.34
# Saving fake_images-0256.png
# Epoch [256/300], Step [200/600], d_loss: 0.9580, g_loss: 1.6103, D(x): 0.69, D(G(z)): 0.32
# Epoch [256/300], Step [400/600], d_loss: 0.8566, g_loss: 1.2805, D(x): 0.73, D(G(z)): 0.33
# Epoch [256/300], Step [600/600], d_loss: 1.0136, g_loss: 1.3718, D(x): 0.70, D(G(z)): 0.37
# Saving fake_images-0257.png
# Epoch [257/300], Step [200/600], d_loss: 0.9523, g_loss: 1.3882, D(x): 0.68, D(G(z)): 0.30
# Epoch [257/300], Step [400/600], d_loss: 1.0448, g_loss: 1.5064, D(x): 0.67, D(G(z)): 0.33
# Epoch [257/300], Step [600/600], d_loss: 0.9955, g_loss: 1.4301, D(x): 0.62, D(G(z)): 0.26
# Saving fake_images-0258.png
# Epoch [258/300], Step [200/600], d_loss: 0.9360, g_loss: 1.5002, D(x): 0.65, D(G(z)): 0.29
# Epoch [258/300], Step [400/600], d_loss: 0.8641, g_loss: 1.3703, D(x): 0.72, D(G(z)): 0.28
# Epoch [258/300], Step [600/600], d_loss: 0.9438, g_loss: 1.4799, D(x): 0.68, D(G(z)): 0.30
# Saving fake_images-0259.png
# Epoch [259/300], Step [200/600], d_loss: 1.0458, g_loss: 1.3011, D(x): 0.69, D(G(z)): 0.38
# Epoch [259/300], Step [400/600], d_loss: 1.0487, g_loss: 1.4659, D(x): 0.70, D(G(z)): 0.37
# Epoch [259/300], Step [600/600], d_loss: 0.9693, g_loss: 1.5335, D(x): 0.66, D(G(z)): 0.30
# Saving fake_images-0260.png
# Epoch [260/300], Step [200/600], d_loss: 1.0429, g_loss: 1.4687, D(x): 0.64, D(G(z)): 0.32
# Epoch [260/300], Step [400/600], d_loss: 0.7975, g_loss: 1.5699, D(x): 0.77, D(G(z)): 0.31
# Epoch [260/300], Step [600/600], d_loss: 0.9267, g_loss: 1.5782, D(x): 0.66, D(G(z)): 0.29
# Saving fake_images-0261.png
# Epoch [261/300], Step [200/600], d_loss: 0.8608, g_loss: 1.4222, D(x): 0.74, D(G(z)): 0.34
# Epoch [261/300], Step [400/600], d_loss: 0.9862, g_loss: 1.3866, D(x): 0.69, D(G(z)): 0.34
# Epoch [261/300], Step [600/600], d_loss: 0.8883, g_loss: 1.5008, D(x): 0.73, D(G(z)): 0.31
# Saving fake_images-0262.png
# Epoch [262/300], Step [200/600], d_loss: 0.9248, g_loss: 1.4094, D(x): 0.69, D(G(z)): 0.31
# Epoch [262/300], Step [400/600], d_loss: 0.8596, g_loss: 1.4011, D(x): 0.76, D(G(z)): 0.34
# Epoch [262/300], Step [600/600], d_loss: 1.0414, g_loss: 1.5737, D(x): 0.67, D(G(z)): 0.35
# Saving fake_images-0263.png
# Epoch [263/300], Step [200/600], d_loss: 1.0373, g_loss: 1.6186, D(x): 0.67, D(G(z)): 0.34
# Epoch [263/300], Step [400/600], d_loss: 0.9791, g_loss: 1.3229, D(x): 0.67, D(G(z)): 0.32
# Epoch [263/300], Step [600/600], d_loss: 1.0406, g_loss: 1.2516, D(x): 0.66, D(G(z)): 0.35
# Saving fake_images-0264.png
# Epoch [264/300], Step [200/600], d_loss: 0.8398, g_loss: 1.7395, D(x): 0.74, D(G(z)): 0.30
# Epoch [264/300], Step [400/600], d_loss: 0.9906, g_loss: 1.2316, D(x): 0.66, D(G(z)): 0.33
# Epoch [264/300], Step [600/600], d_loss: 1.0543, g_loss: 1.5237, D(x): 0.68, D(G(z)): 0.35
# Saving fake_images-0265.png
# Epoch [265/300], Step [200/600], d_loss: 0.8822, g_loss: 1.3766, D(x): 0.73, D(G(z)): 0.32
# Epoch [265/300], Step [400/600], d_loss: 0.9856, g_loss: 1.6523, D(x): 0.64, D(G(z)): 0.26
# Epoch [265/300], Step [600/600], d_loss: 0.9913, g_loss: 1.2915, D(x): 0.71, D(G(z)): 0.35
# Saving fake_images-0266.png
# Epoch [266/300], Step [200/600], d_loss: 1.0628, g_loss: 1.3793, D(x): 0.63, D(G(z)): 0.34
# Epoch [266/300], Step [400/600], d_loss: 0.9460, g_loss: 1.5287, D(x): 0.68, D(G(z)): 0.32
# Epoch [266/300], Step [600/600], d_loss: 1.0126, g_loss: 1.3649, D(x): 0.70, D(G(z)): 0.35
# Saving fake_images-0267.png
# Epoch [267/300], Step [200/600], d_loss: 1.0562, g_loss: 1.4935, D(x): 0.65, D(G(z)): 0.34
# Epoch [267/300], Step [400/600], d_loss: 1.0715, g_loss: 1.2521, D(x): 0.70, D(G(z)): 0.42
# Epoch [267/300], Step [600/600], d_loss: 0.9342, g_loss: 1.6855, D(x): 0.67, D(G(z)): 0.27
# Saving fake_images-0268.png
# Epoch [268/300], Step [200/600], d_loss: 0.9078, g_loss: 1.6040, D(x): 0.71, D(G(z)): 0.28
# Epoch [268/300], Step [400/600], d_loss: 0.9517, g_loss: 1.6459, D(x): 0.66, D(G(z)): 0.30
# Epoch [268/300], Step [600/600], d_loss: 0.9303, g_loss: 1.7670, D(x): 0.71, D(G(z)): 0.31
# Saving fake_images-0269.png
# Epoch [269/300], Step [200/600], d_loss: 0.8627, g_loss: 1.7532, D(x): 0.67, D(G(z)): 0.24
# Epoch [269/300], Step [400/600], d_loss: 0.7923, g_loss: 1.3886, D(x): 0.71, D(G(z)): 0.26
# Epoch [269/300], Step [600/600], d_loss: 1.0124, g_loss: 1.6818, D(x): 0.64, D(G(z)): 0.30
# Saving fake_images-0270.png
# Epoch [270/300], Step [200/600], d_loss: 0.8270, g_loss: 1.4715, D(x): 0.75, D(G(z)): 0.32
# Epoch [270/300], Step [400/600], d_loss: 0.9561, g_loss: 1.3215, D(x): 0.65, D(G(z)): 0.29
# Epoch [270/300], Step [600/600], d_loss: 1.0001, g_loss: 1.3910, D(x): 0.64, D(G(z)): 0.29
# Saving fake_images-0271.png
# Epoch [271/300], Step [200/600], d_loss: 1.0048, g_loss: 1.3985, D(x): 0.64, D(G(z)): 0.28
# Epoch [271/300], Step [400/600], d_loss: 0.7903, g_loss: 1.6895, D(x): 0.69, D(G(z)): 0.24
# Epoch [271/300], Step [600/600], d_loss: 0.9209, g_loss: 1.4317, D(x): 0.69, D(G(z)): 0.32
# Saving fake_images-0272.png
# Epoch [272/300], Step [200/600], d_loss: 0.9434, g_loss: 1.4964, D(x): 0.69, D(G(z)): 0.31
# Epoch [272/300], Step [400/600], d_loss: 0.9713, g_loss: 1.4804, D(x): 0.64, D(G(z)): 0.27
# Epoch [272/300], Step [600/600], d_loss: 0.9965, g_loss: 1.5506, D(x): 0.64, D(G(z)): 0.32
# Saving fake_images-0273.png
# Epoch [273/300], Step [200/600], d_loss: 0.9838, g_loss: 1.6065, D(x): 0.70, D(G(z)): 0.32
# Epoch [273/300], Step [400/600], d_loss: 0.9464, g_loss: 1.3165, D(x): 0.70, D(G(z)): 0.34
# Epoch [273/300], Step [600/600], d_loss: 0.9627, g_loss: 1.7208, D(x): 0.67, D(G(z)): 0.31
# Saving fake_images-0274.png
# Epoch [274/300], Step [200/600], d_loss: 0.9779, g_loss: 1.0135, D(x): 0.77, D(G(z)): 0.41
# Epoch [274/300], Step [400/600], d_loss: 0.9600, g_loss: 1.2395, D(x): 0.70, D(G(z)): 0.36
# Epoch [274/300], Step [600/600], d_loss: 0.8623, g_loss: 1.4498, D(x): 0.69, D(G(z)): 0.28
# Saving fake_images-0275.png
# Epoch [275/300], Step [200/600], d_loss: 0.8942, g_loss: 1.5065, D(x): 0.70, D(G(z)): 0.29
# Epoch [275/300], Step [400/600], d_loss: 0.9115, g_loss: 1.5997, D(x): 0.72, D(G(z)): 0.30
# Epoch [275/300], Step [600/600], d_loss: 0.8659, g_loss: 1.4995, D(x): 0.70, D(G(z)): 0.31
# Saving fake_images-0276.png
# Epoch [276/300], Step [200/600], d_loss: 0.8423, g_loss: 1.5584, D(x): 0.71, D(G(z)): 0.30
# Epoch [276/300], Step [400/600], d_loss: 0.9027, g_loss: 1.5052, D(x): 0.68, D(G(z)): 0.30
# Epoch [276/300], Step [600/600], d_loss: 0.9580, g_loss: 1.4957, D(x): 0.72, D(G(z)): 0.35
# Saving fake_images-0277.png
# Epoch [277/300], Step [200/600], d_loss: 0.8577, g_loss: 1.3665, D(x): 0.72, D(G(z)): 0.31
# Epoch [277/300], Step [400/600], d_loss: 0.8045, g_loss: 1.6968, D(x): 0.69, D(G(z)): 0.25
# Epoch [277/300], Step [600/600], d_loss: 0.8969, g_loss: 1.3279, D(x): 0.76, D(G(z)): 0.35
# Saving fake_images-0278.png
# Epoch [278/300], Step [200/600], d_loss: 0.9075, g_loss: 1.2836, D(x): 0.71, D(G(z)): 0.34
# Epoch [278/300], Step [400/600], d_loss: 0.9353, g_loss: 1.7425, D(x): 0.71, D(G(z)): 0.29
# Epoch [278/300], Step [600/600], d_loss: 1.0114, g_loss: 1.7282, D(x): 0.73, D(G(z)): 0.31
# Saving fake_images-0279.png
# Epoch [279/300], Step [200/600], d_loss: 1.0524, g_loss: 1.3288, D(x): 0.73, D(G(z)): 0.37
# Epoch [279/300], Step [400/600], d_loss: 0.8594, g_loss: 1.8770, D(x): 0.72, D(G(z)): 0.31
# Epoch [279/300], Step [600/600], d_loss: 0.9648, g_loss: 1.5984, D(x): 0.65, D(G(z)): 0.30
# Saving fake_images-0280.png
# Epoch [280/300], Step [200/600], d_loss: 0.9227, g_loss: 1.4751, D(x): 0.70, D(G(z)): 0.32
# Epoch [280/300], Step [400/600], d_loss: 0.8017, g_loss: 1.4689, D(x): 0.73, D(G(z)): 0.28
# Epoch [280/300], Step [600/600], d_loss: 1.0382, g_loss: 1.5925, D(x): 0.72, D(G(z)): 0.39
# Saving fake_images-0281.png
# Epoch [281/300], Step [200/600], d_loss: 0.8980, g_loss: 1.4890, D(x): 0.75, D(G(z)): 0.33
# Epoch [281/300], Step [400/600], d_loss: 0.9140, g_loss: 1.3862, D(x): 0.70, D(G(z)): 0.31
# Epoch [281/300], Step [600/600], d_loss: 0.9785, g_loss: 1.7170, D(x): 0.65, D(G(z)): 0.28
# Saving fake_images-0282.png
# Epoch [282/300], Step [200/600], d_loss: 1.0352, g_loss: 1.4527, D(x): 0.65, D(G(z)): 0.34
# Epoch [282/300], Step [400/600], d_loss: 1.0831, g_loss: 1.3407, D(x): 0.71, D(G(z)): 0.34
# Epoch [282/300], Step [600/600], d_loss: 0.9446, g_loss: 1.5716, D(x): 0.64, D(G(z)): 0.27
# Saving fake_images-0283.png
# Epoch [283/300], Step [200/600], d_loss: 0.8789, g_loss: 1.3048, D(x): 0.76, D(G(z)): 0.36
# Epoch [283/300], Step [400/600], d_loss: 0.9573, g_loss: 1.2551, D(x): 0.74, D(G(z)): 0.38
# Epoch [283/300], Step [600/600], d_loss: 0.8520, g_loss: 1.4951, D(x): 0.72, D(G(z)): 0.29
# Saving fake_images-0284.png
# Epoch [284/300], Step [200/600], d_loss: 0.9368, g_loss: 1.5395, D(x): 0.67, D(G(z)): 0.29
# Epoch [284/300], Step [400/600], d_loss: 0.9189, g_loss: 1.3577, D(x): 0.71, D(G(z)): 0.33
# Epoch [284/300], Step [600/600], d_loss: 0.9421, g_loss: 1.4184, D(x): 0.67, D(G(z)): 0.29
# Saving fake_images-0285.png
# Epoch [285/300], Step [200/600], d_loss: 1.0019, g_loss: 1.4778, D(x): 0.68, D(G(z)): 0.33
# Epoch [285/300], Step [400/600], d_loss: 0.9249, g_loss: 1.5862, D(x): 0.71, D(G(z)): 0.31
# Epoch [285/300], Step [600/600], d_loss: 1.0504, g_loss: 1.2217, D(x): 0.69, D(G(z)): 0.37
# Saving fake_images-0286.png
# Epoch [286/300], Step [200/600], d_loss: 0.9691, g_loss: 1.3540, D(x): 0.72, D(G(z)): 0.35
# Epoch [286/300], Step [400/600], d_loss: 0.9942, g_loss: 1.4554, D(x): 0.70, D(G(z)): 0.36
# Epoch [286/300], Step [600/600], d_loss: 1.0599, g_loss: 1.2918, D(x): 0.64, D(G(z)): 0.35
# Saving fake_images-0287.png
# Epoch [287/300], Step [200/600], d_loss: 0.9704, g_loss: 1.3753, D(x): 0.66, D(G(z)): 0.34
# Epoch [287/300], Step [400/600], d_loss: 1.0157, g_loss: 1.5489, D(x): 0.71, D(G(z)): 0.38
# Epoch [287/300], Step [600/600], d_loss: 1.1034, g_loss: 1.2720, D(x): 0.66, D(G(z)): 0.36
# Saving fake_images-0288.png
# Epoch [288/300], Step [200/600], d_loss: 0.8560, g_loss: 1.3977, D(x): 0.74, D(G(z)): 0.32
# Epoch [288/300], Step [400/600], d_loss: 0.9944, g_loss: 1.6927, D(x): 0.69, D(G(z)): 0.30
# Epoch [288/300], Step [600/600], d_loss: 1.0156, g_loss: 1.4327, D(x): 0.72, D(G(z)): 0.37
# Saving fake_images-0289.png
# Epoch [289/300], Step [200/600], d_loss: 0.8238, g_loss: 1.3850, D(x): 0.76, D(G(z)): 0.32
# Epoch [289/300], Step [400/600], d_loss: 1.0079, g_loss: 1.4222, D(x): 0.73, D(G(z)): 0.39
# Epoch [289/300], Step [600/600], d_loss: 0.9988, g_loss: 1.7171, D(x): 0.67, D(G(z)): 0.32
# Saving fake_images-0290.png
# Epoch [290/300], Step [200/600], d_loss: 0.8467, g_loss: 1.4010, D(x): 0.71, D(G(z)): 0.29
# Epoch [290/300], Step [400/600], d_loss: 0.7918, g_loss: 1.6327, D(x): 0.73, D(G(z)): 0.27
# Epoch [290/300], Step [600/600], d_loss: 1.0703, g_loss: 1.6333, D(x): 0.68, D(G(z)): 0.36
# Saving fake_images-0291.png
# Epoch [291/300], Step [200/600], d_loss: 0.9701, g_loss: 1.3515, D(x): 0.69, D(G(z)): 0.37
# Epoch [291/300], Step [400/600], d_loss: 0.8807, g_loss: 1.4420, D(x): 0.69, D(G(z)): 0.28
# Epoch [291/300], Step [600/600], d_loss: 0.8135, g_loss: 1.6916, D(x): 0.74, D(G(z)): 0.30
# Saving fake_images-0292.png
# Epoch [292/300], Step [200/600], d_loss: 1.0019, g_loss: 1.7552, D(x): 0.67, D(G(z)): 0.35
# Epoch [292/300], Step [400/600], d_loss: 0.7949, g_loss: 1.7983, D(x): 0.70, D(G(z)): 0.22
# Epoch [292/300], Step [600/600], d_loss: 0.8816, g_loss: 1.6583, D(x): 0.68, D(G(z)): 0.28
# Saving fake_images-0293.png
# Epoch [293/300], Step [200/600], d_loss: 0.8233, g_loss: 1.4492, D(x): 0.72, D(G(z)): 0.30
# Epoch [293/300], Step [400/600], d_loss: 0.9755, g_loss: 1.5583, D(x): 0.64, D(G(z)): 0.27
# Epoch [293/300], Step [600/600], d_loss: 0.8152, g_loss: 1.5028, D(x): 0.72, D(G(z)): 0.29
# Saving fake_images-0294.png
# Epoch [294/300], Step [200/600], d_loss: 0.8379, g_loss: 1.5135, D(x): 0.67, D(G(z)): 0.26
# Epoch [294/300], Step [400/600], d_loss: 0.9450, g_loss: 1.8242, D(x): 0.68, D(G(z)): 0.25
# Epoch [294/300], Step [600/600], d_loss: 0.9483, g_loss: 1.5115, D(x): 0.68, D(G(z)): 0.31
# Saving fake_images-0295.png
# Epoch [295/300], Step [200/600], d_loss: 0.9435, g_loss: 1.5950, D(x): 0.67, D(G(z)): 0.29
# Epoch [295/300], Step [400/600], d_loss: 0.8754, g_loss: 1.6330, D(x): 0.70, D(G(z)): 0.28
# Epoch [295/300], Step [600/600], d_loss: 1.1306, g_loss: 1.5995, D(x): 0.61, D(G(z)): 0.31
# Saving fake_images-0296.png
# Epoch [296/300], Step [200/600], d_loss: 0.9414, g_loss: 1.7063, D(x): 0.68, D(G(z)): 0.27
# Epoch [296/300], Step [400/600], d_loss: 0.8532, g_loss: 1.3923, D(x): 0.75, D(G(z)): 0.31
# Epoch [296/300], Step [600/600], d_loss: 0.9630, g_loss: 1.5552, D(x): 0.64, D(G(z)): 0.27
# Saving fake_images-0297.png
# Epoch [297/300], Step [200/600], d_loss: 0.9061, g_loss: 1.4891, D(x): 0.72, D(G(z)): 0.33
# Epoch [297/300], Step [400/600], d_loss: 1.0405, g_loss: 1.6699, D(x): 0.63, D(G(z)): 0.29
# Epoch [297/300], Step [600/600], d_loss: 0.8472, g_loss: 1.5126, D(x): 0.73, D(G(z)): 0.30
# Saving fake_images-0298.png
# Epoch [298/300], Step [200/600], d_loss: 0.7666, g_loss: 1.3561, D(x): 0.74, D(G(z)): 0.27
# Epoch [298/300], Step [400/600], d_loss: 0.9199, g_loss: 1.5224, D(x): 0.66, D(G(z)): 0.25
# Epoch [298/300], Step [600/600], d_loss: 0.8780, g_loss: 1.4666, D(x): 0.69, D(G(z)): 0.27
# Saving fake_images-0299.png
# Epoch [299/300], Step [200/600], d_loss: 1.0050, g_loss: 1.2747, D(x): 0.68, D(G(z)): 0.36
# Epoch [299/300], Step [400/600], d_loss: 0.8992, g_loss: 1.6309, D(x): 0.67, D(G(z)): 0.28
# Epoch [299/300], Step [600/600], d_loss: 0.7993, g_loss: 1.4729, D(x): 0.75, D(G(z)): 0.29
# Saving fake_images-0300.png
# Wall time: 45min 40s

# %%
# show sample of Generator output after epochs training
Image(os.path.join(sample_dir, 'fake_images-0225.png'))

# %%
# show the discrimator loss and generator loss
plt.plot(d_losses, '-')
plt.plot(g_losses, '-')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['Discriminator', 'Generator'])
plt.title('Losses');

# %%
# plot the accuracy of discrimator
plt.plot(real_scores, '-')
plt.plot(fake_scores, '-')
plt.xlabel('epoch')
plt.ylabel('score')
plt.legend(['Real Score', 'Fake score'])
plt.title('Scores');
